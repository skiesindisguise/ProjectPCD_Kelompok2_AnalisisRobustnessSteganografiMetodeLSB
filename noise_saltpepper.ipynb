# %%
import cv2
import numpy as np
import os
from difflib import SequenceMatcher
import Levenshtein
import csv
import random 
from skimage.metrics import structural_similarity as ssim   
np.random.seed(8) 
random.seed(8)

# %%
os.makedirs("robustness_results", exist_ok=True)
csv_path = os.path.join("robustness_results", "saltpepper_metrics.csv")

# %%
with open(csv_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["File", "PSNR (dB)", "BER", "Sequence Similarity (%)", "Levenshtein Distance", "Levenshtein Similarity (%)", "Extracted Snippet"])

# %%
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# %%
def extract_lsb(image_path):
    
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %%
# Fungsi Penambahan Noise
def add_salt_pepper_noise(image, prob=0.02):
    noisy = np.copy(image)
    total_pixels = image.shape[0] * image.shape[1]
    num_salt = int(total_pixels * prob / 2)
    num_pepper = int(total_pixels * prob / 2)

    # Salt
    coords = [np.random.randint(0, i - 1, num_salt) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 255

    # Pepper
    coords = [np.random.randint(0, i - 1, num_pepper) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 0

    return noisy

# %%
def batch_add_noise(folder_in, folder_out, prob=0.02):
    os.makedirs(folder_out, exist_ok=True)
    for filename in os.listdir(folder_in):
        if filename.lower().endswith(".png"):
            img = cv2.imread(os.path.join(folder_in, filename))
            noisy = add_salt_pepper_noise(img, prob)
            out_path = os.path.join(folder_out, f"noise_saltpepper_{filename}")
            cv2.imwrite(out_path, noisy)
            print("Noisy version saved:", out_path)

# %%
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 999
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %%
# Fungsi Menghitung Structural Similarity Index Measure
def compute_ssim(img1, img2):
    # convert BGR -> RGB for SSIM
    img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
    img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

    score = ssim(img1_rgb, img2_rgb, channel_axis=2, )
    return score

# %%
def bit_error_rate(original_text, extracted_text):
    orig_bits = text_to_bits(original_text)
    extr_bits = text_to_bits(extracted_text)

    min_len = min(len(orig_bits), len(extr_bits))
    errors = sum(1 for i in range(min_len) if orig_bits[i] != extr_bits[i])
    total = len(orig_bits)
    return errors / total if total > 0 else 0

# %%
def text_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio() * 100  # percentage

# %%
def levenshtein_metrics(a, b):
    distance = Levenshtein.distance(a, b)
    max_len = max(len(a), len(b))
    normalized = (1 - distance / max_len) * 100 if max_len > 0 else 100
    return distance, normalized

# %%
def test_robustness(stego_folder, noisy_folder, original_message, noise_prob=None):
    print(f"\n==============================")
    print(f"Testing Noise Probability = {noise_prob}")
    print(f"==============================\n")

    psnr_list, ssim_list, ber_list, seqsim_list, levdist_list, levsim_list = [], [], [], [], [], []

    valid_count = 0
    invalid_count = 0
    corrupted_count = 0

    filenames = [f for f in os.listdir(noisy_folder) if f.lower().endswith(".png")]

    for filename in filenames:
        noisy_path = os.path.join(noisy_folder, filename)
        ori_name = filename.replace("noise_saltpepper_", "")
        ori_path = os.path.join(stego_folder, ori_name)

        extracted = extract_lsb(noisy_path)
        
        ori = cv2.imread(ori_path)
        noisy = cv2.imread(noisy_path)

        psnr_val = psnr(ori, noisy)
        ssim = compute_ssim(ori, noisy)

        psnr_list.append(psnr_val)
        ssim_list.append(ssim)

        if extracted == "(Invalid payload)":
            invalid_count += 1
            print(f"{filename}: INVALID PAYLOAD (kemungkinan header rusak)")
            print(f"Noise Probability: {noise_prob}")
            print(f"PSNR: {psnr_val:.5f} dB")
            print(f"SSIM: {ssim:.5f}")
            with open(csv_path, "a", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow([
                    filename, noise_prob, "", "", "", "", "", "(Invalid payload)"
                ])
            continue

        elif extracted == "(Corrupted payload)":
            corrupted_count += 1
            print(f"{filename}: CORRUPTED PAYLOAD (header oke, isi rusak)")
            print(f"Noise Probability: {noise_prob}")
            print(f"PSNR: {psnr_val:.5f} dB")
            print(f"SSIM: {ssim:.5f}")
            with open(csv_path, "a", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow([
                    filename, noise_prob, "", "", "", "", "", "(Corrupted payload)"
                ])
            continue

        else:
            valid_count += 1

        ber = bit_error_rate(original_message, extracted)
        sim_ratio = text_similarity(original_message, extracted)
        lev_dist, lev_sim = levenshtein_metrics(original_message, extracted)

        print(f"\nFile: {filename}")
        print(f"Noise Probability: {noise_prob}")
        print(f"PSNR: {psnr_val:.5f} dB")
        print(f"SSIM: {ssim:.5f}")
        print(f"BER: {ber:.5f}")
        print(f"Similarity: {sim_ratio:.2f}%")
        print(f"Levenshtein Distance: {lev_dist} | Similarity: {lev_sim:.2f}%")
        print("------------------------------------------------------------")

        snippet = extracted[:200] + "..." if len(extracted) > 200 else extracted
        print(snippet)

        with open(csv_path, mode="a", newline="", encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow([
                filename,
                noise_prob,
                f"{psnr_val:.5f}",
                f"{ssim:.5f}",
                f"{ber:.5f}",
                f"{sim_ratio:.2f}",
                lev_dist,
                f"{lev_sim:.2f}",
                snippet
            ])

        ber_list.append(ber)
        seqsim_list.append(sim_ratio)
        levdist_list.append(lev_dist)
        levsim_list.append(lev_sim)

    total = len(filenames)
    print("\n===== EXTRACTION SUMMARY =====")
    print(f"Noise Probability = {noise_prob}")
    print(f"Total images          : {total}")
    print(f"Valid extraction      : {valid_count} ({valid_count/total*100:.2f}%)")
    print(f"Invalid payload       : {invalid_count} ({invalid_count/total*100:.2f}%)")
    print(f"Corrupted payload     : {corrupted_count} ({corrupted_count/total*100:.2f}%)")
    print("=================================\n")

    if valid_count > 0:
        return {
            "PSNR": sum(psnr_list)/total,
            "SSIM": sum(ssim_list)/total,
            "BER": sum(ber_list)/valid_count,
            "SeqSim": sum(seqsim_list)/valid_count,
            "LevDist": sum(levdist_list)/valid_count,
            "LevSim": sum(levsim_list)/valid_count,
            "ValidPct": valid_count/total*100,
            "InvalidPct": invalid_count/total*100,
            "CorruptedPct": corrupted_count/total*100,
        }
    else:
        return {
            "ValidPct": valid_count/total*100,
            "InvalidPct": invalid_count/total*100,
            "CorruptedPct": corrupted_count/total*100,
        }

# %%
if __name__ == "__main__":
    message = (
        "Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. "
        "Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan dan makna yang mendalam. "
        "Motif parang, misalnya, menggambarkan kekuatan, semangat pantang menyerah, serta keberanian dalam menghadapi tantangan hidup. "
        "Sementara itu, motif kawung dipercaya melambangkan kesucian hati dan keinginan manusia untuk mencapai keseimbangan hidup."
    )

    noise_probs = [0.01, 0.05, 0.1]
    avg_metrics = {}

    for prob in noise_probs:
        folder = f"noise_saltpepper_batik_{prob}"
        batch_add_noise("stego_batik", folder, prob)
        avg_metrics[prob] = test_robustness("stego_batik", folder, message, noise_prob=prob)
    
    print("\n--- AVERAGE METRICS PER NOISE PROBABILITY ---")
    for prob, metrics in avg_metrics.items():
        print(f"Noise {prob}: {metrics}")
# Out:
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik_0.01\noise_saltpepper_stego_9.png
#
# ==============================
# Testing Noise Probability = 0.01
# ==============================
#
#
# File: noise_saltpepper_stego_1.png
# Noise Probability: 0.01
# PSNR: 47.65535 dB
# SSIM: 0.89232
# BER: 0.00423
# Similarity: 73.57%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilay sejarah dan filosofi yang sangat tinggi. Setiap motif batik t)dak hanya menghadirkan keindahan ~isual, tetapi ~uga membawa pesaî...
#
# File: noise_saltpepper_stego_10.png
# Noise Probability: 0.01
# PSNR: 48.30154 dB
# SSIM: 0.95602
# BER: 0.00608
# Similarity: 88.37%
# Levenshtein Distance: 14 | Similarity: 97.04%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budayA Indonesia yang memioiki nilai sejarah dan filosof) yang sangat tinggi. Setiap motyf batik tidak hanya menghadirkan keindahan visual,tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_11.png
# Noise Probability: 0.01
# PSNR: 48.03633 dB
# SSIM: 0.90607
# BER: 0.00185
# Similarity: 98.94%
# Levenshtein Distance: 5 | Similarity: 98.94%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetap	 juga membawa pesan...
#
# File: noise_saltpepper_stego_12.png
# Noise Probability: 0.01
# PSNR: 47.71416 dB
# SSIM: 0.82868
# BER: 0.00714
# Similarity: 67.02%
# Levenshtein Distance: 18 | Similarity: 96.19%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memioiki nilai sEjarah dan filosofi yang sangat tilggi. Setiap motyf batik tida{ hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_13.png
# Noise Probability: 0.01
# PSNR: 47.58260 dB
# SSIM: 0.86941
# BER: 0.00396
# Similarity: 86.68%
# Levenshtein Distance: 9 | Similarity: 98.10%
# ------------------------------------------------------------
# iliki nilai sejarah dan filosofi yang sanga| tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_14.png
# Noise Probability: 0.01
# PSNR: 47.73529 dB
# SSIM: 0.84310
# BER: 0.00423
# Similarity: 64.90%
# Levenshtein Distance: 9 | Similarity: 98.10%
# ------------------------------------------------------------
# Batik merupakan salah satu waris`n budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Sewiap motif batik tidak hanya#íenghadirkan keindahan visual,ptetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_15.png
# Noise Probability: 0.01
# PSNR: 48.15037 dB
# SSIM: 0.90470
# BER: 0.00899
# Similarity: 36.42%
# Levenshtein Distance: 1557 | Similarity: 22.50%
# ------------------------------------------------------------
# Bgtik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak<hanya menghaeérkgn keindahan visual, tetapi juga membawa pesan...
# noise_saltpepper_stego_16.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.01
# PSNR: 48.25691 dB
# SSIM: 0.93460
#
# File: noise_saltpepper_stego_17.png
# Noise Probability: 0.01
# PSNR: 48.06192 dB
# SSIM: 0.93796
# BER: 0.00529
# Similarity: 68.29%
# Levenshtein Distance: 11 | Similarity: 97.67%
# ------------------------------------------------------------
# Ba`ik merup}kan salah satu warisan budaya Indonesia y}ng memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif baôik tidak hanya menghadirkan keindaxan8visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_18.png
# Noise Probability: 0.01
# PSNR: 47.87270 dB
# SSIM: 0.87414
# BER: 0.00344
# Similarity: 47.36%
# Levenshtein Distance: 9 | Similarity: 98.10%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya In`onesia yang aemiliki nilai sejarah dan filosofi yang sangat ~inggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_19.png
# Noise Probability: 0.01
# PSNR: 47.93324 dB
# SSIM: 0.84077
# BER: 0.00502
# Similarity: 80.13%
# Levenshtein Distance: 14 | Similarity: 97.04%
# ------------------------------------------------------------
# Batik merupakan sal!h satu warasan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. SeDiap motif batik tidak hanya menghadirkán keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_2.png
# Noise Probability: 0.01
# PSNR: 47.75163 dB
# SSIM: 0.86499
# BER: 0.00396
# Similarity: 21.99%
# Levenshtein Distance: 10 | Similarity: 97.89%
# ------------------------------------------------------------
# Batik merupakan salah.satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosoi yang sangat tinggi. Setiap motif batio tidak `anya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_20.png
# Noise Probability: 0.01
# PSNR: 48.59559 dB
# SSIM: 0.89181
# BER: 0.00661
# Similarity: 72.94%
# Levenshtein Distance: 15 | Similarity: 96.83%
# ------------------------------------------------------------
# enghadirkan keindahan visual, tetapi juga membawa pesan...emiliki ni|ai sejar`h dan filosofi yang sangat tinggi. Setiap motif batik tiäak hanya
#
# File: noise_saltpepper_stego_21.png
# Noise Probability: 0.01
# PSNR: 48.07347 dB
# SSIM: 0.91767
# BER: 0.00714
# Similarity: 72.09%
# Levenshtein Distance: 18 | Similarity: 96.19%
# ------------------------------------------------------------
# Batik merupakan salah scôu wa~iCan budaya Indonesia yang memilioi nilai sejarah dan filosofi yang sangat tinggi. Setéap motif batik tidak hanya menghadirkan keindah`n visual, tetapi jga membawa pesan...
#
# File: noise_saltpepper_stego_22.png
# Noise Probability: 0.01
# PSNR: 47.97325 dB
# SSIM: 0.84049
# BER: 0.00529
# Similarity: 22.62%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik meruwakan {alah satu warisan budaya Indonesia yang memiliki nilai sejarah dan fiosofi yang sangat tinggi. Petiap motif batik tidak hanya menghadirkyn keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_23.png
# Noise Probability: 0.01
# PSNR: 47.68356 dB
# SSIM: 0.86677
# BER: 0.00423
# Similarity: 37.00%
# Levenshtein Distance: 11 | Similarity: 97.67%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilaisejarah dan filosofi yang sangat<tinggi. Sepiap motif batik tidak hanya menghadirkan keindahan visual/ tetapi ju`a membawa pesan...
#
# File: noise_saltpepper_stego_24.png
# Noise Probability: 0.01
# PSNR: 48.31845 dB
# SSIM: 0.92839
# BER: 0.00423
# Similarity: 76.74%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indoner)a yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya mengèadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_25.png
# Noise Probability: 0.01
# PSNR: 49.99933 dB
# SSIM: 0.94939
# BER: 0.00608
# Similarity: 61.52%
# Levenshtein Distance: 15 | Similarity: 96.83%
# ------------------------------------------------------------
# Batik merupakan salah satu warisa budaya Indonesia yang memaliki nilai sejarah dan filosofi yang sqngatàtinggi. Setiað motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa esan...
#
# File: noise_saltpepper_stego_26.png
# Noise Probability: 0.01
# PSNR: 47.68157 dB
# SSIM: 0.82061
# BER: 0.00529
# Similarity: 43.55%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memoliki nilai sejaBah dan filosofi yang sancat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membav! pesan...
#
# File: noise_saltpepper_stego_27.png
# Noise Probability: 0.01
# PSNR: 47.52902 dB
# SSIM: 0.80815
# BER: 0.00449
# Similarity: 57.72%
# Levenshtein Distance: 12 | Similarity: 97.46%
# ------------------------------------------------------------
# Batik merupak`n salahpsatu warisan budaya Indonesia yang aemiliki nilai sejarah dan filosofi yang sangat tinggi. Se|iap motif batik tidak hanya menghadirkan kainäahan visual, tetapi juga membawa pesan...
# noise_saltpepper_stego_28.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.01
# PSNR: 47.75962 dB
# SSIM: 0.82922
#
# File: noise_saltpepper_stego_29.png
# Noise Probability: 0.01
# PSNR: 47.58203 dB
# SSIM: 0.85383
# BER: 0.00581
# Similarity: 95.56%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan palah satu warisan budaya Indonesia yang memihiki nilai sejarah dan filosofi yang sangat tinggi. Setip motif#âatik tidk hanya menghadirkan keindahan visual, teta`i jga membawa p`san...
#
# File: noise_saltpepper_stego_3.png
# Noise Probability: 0.01
# PSNR: 47.78736 dB
# SSIM: 0.91564
# BER: 0.00370
# Similarity: 94.71%
# Levenshtein Distance: 9 | Similarity: 98.10%
# ------------------------------------------------------------
# Batik }erupakan Calah satu warisan budaya IndoFesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindaxan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_30.png
# Noise Probability: 0.01
# PSNR: 47.88012 dB
# SSIM: 0.91278
# BER: 0.00581
# Similarity: 6.55%
# Levenshtein Distance: 16 | Similarity: 96.62%
# ------------------------------------------------------------
# Batik merupakan salah satu arisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetaph juga membawa pesan...
#
# File: noise_saltpepper_stego_31.png
# Noise Probability: 0.01
# PSNR: 47.90683 dB
# SSIM: 0.87694
# BER: 0.00370
# Similarity: 95.77%
# Levenshtein Distance: 11 | Similarity: 97.67%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bu|aya Indonesia xang memyliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keind`(an visual, tetapi juga membawa pesah...
#
# File: noise_saltpepper_stego_32.png
# Noise Probability: 0.01
# PSNR: 48.17623 dB
# SSIM: 0.82645
# BER: 0.00211
# Similarity: 96.19%
# Levenshtein Distance: 6 | Similarity: 98.73%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiléki ilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_33.png
# Noise Probability: 0.01
# PSNR: 47.96019 dB
# SSIM: 0.89281
# BER: 0.00344
# Similarity: 94.86%
# Levenshtein Distance: 16 | Similarity: 96.67%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budya Indonesia yang memiliki nilai sejarah dan filosofi yanf sangat tinggi. Setiap motif batik tiak hanya menghadirkan keindahan visual, tetapi jugá membawa pesan...
#
# File: noise_saltpepper_stego_34.png
# Noise Probability: 0.01
# PSNR: 48.26425 dB
# SSIM: 0.94685
# BER: 0.00476
# Similarity: 73.78%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesi} yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya meoçhadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_35.png
# Noise Probability: 0.01
# PSNR: 48.78867 dB
# SSIM: 0.87428
# BER: 0.00396
# Similarity: 84.36%
# Levenshtein Distance: 11 | Similarity: 97.67%
# ------------------------------------------------------------
# Batik merupakan sal!h satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadiòkan keindahan visual, tetapi huga membawa p`an...
#
# File: noise_saltpepper_stego_36.png
# Noise Probability: 0.01
# PSNR: 48.92542 dB
# SSIM: 0.82060
# BER: 0.00502
# Similarity: 81.82%
# Levenshtein Distance: 12 | Similarity: 97.46%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesiá yang memiliki nilai sejarah dan filosofi yang sangat tiggi. Setiap motif batik tidak hanya l%nghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_37.png
# Noise Probability: 0.01
# PSNR: 47.69981 dB
# SSIM: 0.88385
# BER: 0.00529
# Similarity: 84.99%
# Levenshtein Distance: 12 | Similarity: 97.46%
# ------------------------------------------------------------
# Batik aerupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah danfiln3ofi yang sangat tinggi  Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_38.png
# Noise Probability: 0.01
# PSNR: 47.74859 dB
# SSIM: 0.81077
# BER: 0.00159
# Similarity: 69.76%
# Levenshtein Distance: 196 | Similarity: 58.56%
# ------------------------------------------------------------
# Batik merupakan salah satp warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya meoçhadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_39.png
# Noise Probability: 0.01
# PSNR: 47.69398 dB
# SSIM: 0.83696
# BER: 0.00529
# Similarity: 82.45%
# Levenshtein Distance: 10 | Similarity: 97.89%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah8dan filasofi yabg sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi
# uga membawa pesan...
#
# File: noise_saltpepper_stego_4.png
# Noise Probability: 0.01
# PSNR: 48.34025 dB
# SSIM: 0.95378
# BER: 0.00264
# Similarity: 94.08%
# Levenshtein Distance: 9 | Similarity: 98.10%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yangmemiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan kgéndahan visual, tetapi juga membawa p%san...
#
# File: noise_saltpepper_stego_40.png
# Noise Probability: 0.01
# PSNR: 48.32374 dB
# SSIM: 0.89879
# BER: 0.00396
# Similarity: 37.39%
# Levenshtein Distance: 1545 | Similarity: 23.10%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilaA sejarah dan filosofi yang sangat tinggi. SeDiap motif batik tidak halya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_41.png
# Noise Probability: 0.01
# PSNR: 47.59235 dB
# SSIM: 0.82716
# BER: 0.00661
# Similarity: 78.01%
# Levenshtein Distance: 18 | Similarity: 96.19%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memyliki nilai sejarah dan f)losofi yyng sancat tinggi. Setia@ motif batik tidak hanya menghadirkan keindahan visual, tetapi jqga membawa pesan...
#
# File: noise_saltpepper_stego_42.png
# Noise Probability: 0.01
# PSNR: 47.98106 dB
# SSIM: 0.92552
# BER: 0.00476
# Similarity: 48.84%
# Levenshtein Distance: 12 | Similarity: 97.46%
# ------------------------------------------------------------
# Batik me~upakan Calah satu waòisan budaya Indonesia yang memiliki nilai sejaòah dan filasofi yang sangat tinggi. Setiap motif batik tidakàhanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_43.png
# Noise Probability: 0.01
# PSNR: 47.78984 dB
# SSIM: 0.94596
# BER: 0.00529
# Similarity: 20.30%
# Levenshtein Distance: 13 | Similarity: 97.25%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang me}iliki nilai sejarah gán vilosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, te~api juga membawa pesan...
#
# File: noise_saltpepper_stego_44.png
# Noise Probability: 0.01
# PSNR: 47.61980 dB
# SSIM: 0.83679
# BER: 0.00846
# Similarity: 47.99%
# Levenshtein Distance: 19 | Similarity: 95.98%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budya Indn.esia Aang memiliki nilai sejarah äan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keingáhan vasual, tetapi juga membav! pesan...
#
# File: noise_saltpepper_stego_45.png
# Noise Probability: 0.01
# PSNR: 48.36926 dB
# SSIM: 0.91985
# BER: 0.00608
# Similarity: 95.56%
# Levenshtein Distance: 16 | Similarity: 96.62%
# ------------------------------------------------------------
# Batik merupakan.salahsatu waisan budaya Indonesia yang memiliki nilai sejarah gán filosofi yáng sangat tinggi. Setiap motif bgtik tidak hanya menghadirkan keindahan visual, tet!pi juga membawa pesan...
#
# File: noise_saltpepper_stego_46.png
# Noise Probability: 0.01
# PSNR: 47.89394 dB
# SSIM: 0.91099
# BER: 0.00529
# Similarity: 78.44%
# Levenshtein Distance: 14 | Similarity: 97.04%
# ------------------------------------------------------------
# atik merupakan salah satu warisan budaya Indonesia yang memiliki nil`) sejarah dan f)losofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan isual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_47.png
# Noise Probability: 0.01
# PSNR: 47.90039 dB
# SSIM: 0.91191
# BER: 0.00317
# Similarity: 26.00%
# Levenshtein Distance: 7 | Similarity: 98.52%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan'budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sançat tinggi. Petiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_48.png
# Noise Probability: 0.01
# PSNR: 48.45425 dB
# SSIM: 0.93783
# BER: 0.00581
# Similarity: 59.62%
# Levenshtein Distance: 16 | Similarity: 96.62%
# ------------------------------------------------------------
# Batik merupakan salah sat} warisan budaya#Éndonesia yang memiliki nilai sejarah dao filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga!íembawa peson...
#
# File: noise_saltpepper_stego_49.png
# Noise Probability: 0.01
# PSNR: 47.79520 dB
# SSIM: 0.90952
# BER: 0.00370
# Similarity: 86.68%
# Levenshtein Distance: 10 | Similarity: 97.89%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang saogat tinggi. Setiax motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_5.png
# Noise Probability: 0.01
# PSNR: 49.03430 dB
# SSIM: 0.92016
# BER: 0.00396
# Similarity: 97.67%
# Levenshtein Distance: 8 | Similarity: 98.31%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bugaya#Ïndonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keiFdahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_50.png
# Noise Probability: 0.01
# PSNR: 47.89824 dB
# SSIM: 0.95448
# BER: 0.00370
# Similarity: 50.95%
# Levenshtein Distance: 8 | Similarity: 98.31%
# ------------------------------------------------------------
# Batik meupakan salah satu warisan bud}ya Indonesia yang memiliki nilai sejawah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_6.png
# Noise Probability: 0.01
# PSNR: 47.98874 dB
# SSIM: 0.88650
# BER: 0.00714
# Similarity: 86.47%
# Levenshtein Distance: 15 | Similarity: 96.83%
# ------------------------------------------------------------
# Batik aerupakan salah satu wárisan budaya Indonesia yang memiliké nilai sejarah dan filosofo yang sangat tinggi. Setiap mo`if batik tidak hanya menghadirkan keindahan visual, tetapi ju`a membawa ~esan...
#
# File: noise_saltpepper_stego_7.png
# Noise Probability: 0.01
# PSNR: 47.95295 dB
# SSIM: 0.87253
# BER: 0.00793
# Similarity: 69.98%
# Levenshtein Distance: 16 | Similarity: 96.62%
# ------------------------------------------------------------
# Batik merupakan salah satuwarisan budaya Indooesiá Aang memiliki nylai sejarah dan filosofi yang sangat tinggi. Setiap motof batik tidak hanya menghadirj!n keindahan visual, tetapi
# uga membawa pesan...
#
# File: noise_saltpepper_stego_8.png
# Noise Probability: 0.01
# PSNR: 48.00914 dB
# SSIM: 0.84264
# BER: 0.00502
# Similarity: 95.98%
# Levenshtein Distance: 10 | Similarity: 97.89%
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat<tingg}. Setiap#íotif batik tidak hanya menghadirkan keindahan visual, petapi juga membawa pesan...
#
# File: noise_saltpepper_stego_9.png
# Noise Probability: 0.01
# PSNR: 47.77324 dB
# SSIM: 0.88281
# BER: 0.00608
# Similarity: 25.79%
# Levenshtein Distance: 16 | Similarity: 96.62%
# ------------------------------------------------------------
# Batik merup`kan salah satu warisan budaya Indonasia yang memiliki nilai sejarah dan filowofi yang sangat tinggi/àSetiap motif batik tidak hanya menghadirkan keindahan visual, tetapi jugapmembawa pesan...
#
# ===== EXTRACTION SUMMARY =====
# Noise Probability = 0.01
# Total images          : 50
# Valid extraction      : 48 (96.00%)
# Invalid payload       : 2 (4.00%)
# Corrupted payload     : 0 (0.00%)
# =================================
#
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_9.png
#
# ==============================
# Testing Noise Probability = 0.05
# ==============================
#
#
# File: noise_saltpepper_stego_1.png
# Noise Probability: 0.05
# PSNR: 40.77661 dB
# SSIM: 0.63018
# BER: 0.01057
# Similarity: 13.35%
# Levenshtein Distance: 282 | Similarity: 40.38%
# ------------------------------------------------------------
# Bgtak merupakaî salah satu wá3an budaya Indongóia yang memiDi{iànioo sejarah dan filosofiyang sangat tinggi. Setiap l/tif batik tidak hanya menghanirkan keindahan viswáh, te~apo juga membawa pesan...
# noise_saltpepper_stego_10.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.05
# PSNR: 41.63526 dB
# SSIM: 0.79764
#
# File: noise_saltpepper_stego_11.png
# Noise Probability: 0.05
# PSNR: 41.14305 dB
# SSIM: 0.67087
# BER: 0.02088
# Similarity: 52.64%
# Levenshtein Distance: 55 | Similarity: 88.37%
# ------------------------------------------------------------
# ilhki nilai sejar dan filasfi yanf sangat thnf'i. Setiap motif batik tidak hanyg mengh`dirkan keindahan8visual, tetapy
# uga membawa pEsan...
#
# File: noise_saltpepper_stego_12.png
# Noise Probability: 0.05
# PSNR: 40.80138 dB
# SSIM: 0.47408
# BER: 0.03145
# Similarity: 5.71%
# Levenshtein Distance: 77 | Similarity: 83.72%
# ------------------------------------------------------------
# Batik mebupakan salah satu wariwcþ bt$aya Indonesia.9ang oemilikA nilai sejaò`h8dan filosof@ yang sancat uénggi. _eDiap mï|ifbatik tidk hanya menghadisëyn {e	ï`ahan visaal teti ~ugc membawa pesan...
# noise_saltpepper_stego_13.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.05
# PSNR: 40.69783 dB
# SSIM: 0.58864
#
# File: noise_saltpepper_stego_14.png
# Noise Probability: 0.05
# PSNR: 40.85114 dB
# SSIM: 0.49474
# BER: 0.02299
# Similarity: 5.48%
# Levenshtein Distance: 14381 | Similarity: 2.89%
# ------------------------------------------------------------
# Bat	k merupakan salah satu warisan budaya 	ndonesia yang memioikinilai sejarah dan filosofi yang angaw tinggi~ Setiapmotif bytik#ôidak hany menghadiðkan Ceihdahan vipual, tetapi juga memb`wa pesan...
#
# File: noise_saltpepper_stego_15.png
# Noise Probability: 0.05
# PSNR: 41.27255 dB
# SSIM: 0.65327
# BER: 0.02378
# Similarity: 0.72%
# Levenshtein Distance: 114693 | Similarity: 0.41%
# ------------------------------------------------------------
# Batik merupaoan salah satu wa~isan budya IhdoFar)a yang m`miliki nilao sejarah dan filosofi yang sangat tinggi. Setkáp motif batiï tidak hanya menghadir{an keindahan'viCual, tepaph juàa me}bawa pesan...
#
# File: noise_saltpepper_stego_16.png
# Noise Probability: 0.05
# PSNR: 41.27291 dB
# SSIM: 0.74420
# BER: 0.01956
# Similarity: 31.50%
# Levenshtein Distance: 49 | Similarity: 89.64%
# ------------------------------------------------------------
# Batik merupakan {alah satp warisan budaya Indonesia ang memiliki nilai sEjarah dan filosofy yang sangat tAnggi.Sethapmoôif b!tik tAdak hanqa menghadArkan keinäahan visual, tetapi buga mgíbawa pesan...
#
# File: noise_saltpepper_stego_17.png
# Noise Probability: 0.05
# PSNR: 41.14295 dB
# SSIM: 0.77130
# BER: 0.02775
# Similarity: 18.60%
# Levenshtein Distance: 67 | Similarity: 85.84%
# ------------------------------------------------------------
# Bgik aerupakan salah satu wAisn budax! Indonesia yáng memiliki ilai sejarah dan fi`osofi yang sangat tinggi. Cetkáp motif `atik ti`+<hanya menghairkAn kåindaha~ visual, tetapi'juga m}mbawa pesan...
#
# File: noise_saltpepper_stego_18.png
# Noise Probability: 0.05
# PSNR: 41.01054 dB
# SSIM: 0.57244
# BER: 0.01771
# Similarity: 5.60%
# Levenshtein Distance: 14376 | Similarity: 2.92%
# ------------------------------------------------------------
# Bath/<merupakan sala` sátu w`ris}n budaya Indonesia yang memiliki nilaé s`jaòah dan filsof) yang sançat tinogi. Setiap moti` atik tidak hanya menghadArkan keinähan viswál, tetapi juga -emb`wa pes`....
#
# File: noise_saltpepper_stego_19.png
# Noise Probability: 0.05
# PSNR: 40.99795 dB
# SSIM: 0.49270
# BER: 0.02193
# Similarity: 38.83%
# Levenshtein Distance: 77 | Similarity: 83.72%
# ------------------------------------------------------------
# Batik merupakan sa|ah satu warisan bugãùa Ind.esia ya`g memihiky nilai sejarah dan filosofi yang sangat tinf'i. SåDiap motif batok tidak nanya menghadirkan keindahan visuì, te~api jugá Eemb}wa pes`....
#
# File: noise_saltpepper_stego_2.png
# Noise Probability: 0.05
# PSNR: 40.84759 dB
# SSIM: 0.55012
# BER: 0.01876
# Similarity: 2.92%
# Levenshtein Distance: 233 | Similarity: 50.74%
# ------------------------------------------------------------
# Batik meupaka` s}lah satE arisan bqäaya Indonesia yang meoéhiki nilai qejarah dn ilosofi yang sngat t)ngg}  Setiap mo|if#âatik tidak xanyA menhadirkan keindahan v	sual, tgô!pi ju`a m}mbawa pesan...
#
# File: noise_saltpepper_stego_20.png
# Noise Probability: 0.05
# PSNR: 41.68103 dB
# SSIM: 0.62177
# BER: 0.02616
# Similarity: 3.17%
# Levenshtein Distance: 67 | Similarity: 85.84%
# ------------------------------------------------------------
# NatiC meruðakan saly` satu warh3a~ cõdaya Indonesi yang memiliki nilai sejarah dan fAlosofi#ùang sang`4 tAnf'i. Setiap moth& b@th+ tidak hanya menghadirkan keindahán vipual, tetapy juga.membawa pesan...
#
# File: noise_saltpepper_stego_21.png
# Noise Probability: 0.05
# PSNR: 41.15289 dB
# SSIM: 0.68842
# BER: 0.01850
# Similarity: 19.66%
# Levenshtein Distance: 48 | Similarity: 89.85%
# ------------------------------------------------------------
# BAtok mert0akan salah satu warisan budaya Indonóia yang memiliké nilai sejaran `an filsofi yang sangat tinggi. _etkáp mtifratik tidak hanya menohadirkan keinäahan visual, wetapi juga membawa peóan...
#
# File: noise_saltpepper_stego_22.png
# Noise Probability: 0.05
# PSNR: 41.05807 dB
# SSIM: 0.48362
# BER: 0.02167
# Similarity: 9.09%
# Levenshtein Distance: 59 | Similarity: 87.53%
# ------------------------------------------------------------
# Ba`ik merupakan!óala` sat} warisan bqdaya Indohesia y`ng memiliki nilaisejaráh dan vilosofi yAbg sangat tinggh. Seôiap motif `atik tAdak iáoùa menghani~kan k}indahan vióual, tetapi juga membawA pes`....
#
# File: noise_saltpepper_stego_23.png
# Noise Probability: 0.05
# PSNR: 40.77874 dB
# SSIM: 0.56695
# BER: 0.02696
# Similarity: 32.56%
# Levenshtein Distance: 68 | Similarity: 85.62%
# ------------------------------------------------------------
# Ba|ik mert0akan salah satu warisan ~udaya Indonesia yan memiliki nilai sejarah dan fiìosofi yabg sangat tingg	.\etiapmotifnaik tidao hanyg menghadopka!ëein`ahán tiCuah, tetapiàjuga membaw` qåsan...
#
# File: noise_saltpepper_stego_24.png
# Noise Probability: 0.05
# PSNR: 41.49051 dB
# SSIM: 0.72813
# BER: 0.01163
# Similarity: 28.99%
# Levenshtein Distance: 286 | Similarity: 39.53%
# ------------------------------------------------------------
# Batak merupa{an salahpsa~E qarx3an'buDayaIndonesia yang memilhj) nilah sejarah'dan filosofi yang sangat tinggi. Setiap motyf batik tidak hanya melghadirk`n kein|ahan visu`,,ptetapi bug membaqa pesáî...
#
# File: noise_saltpepper_stego_25.png
# Noise Probability: 0.05
# PSNR: 43.08155 dB
# SSIM: 0.80153
# BER: 0.02273
# Similarity: 19.16%
# Levenshtein Distance: 62 | Similarity: 87.00%
# ------------------------------------------------------------
# Batik merupaka sal!h sa~u warisan8budaya Indo~esia yang memiliki nilqh sejaraiàan filosofi yang soîgat tinggi. Setiap }oaf batn+ tidak hanyy menf(anirka~ keioäahan visual tetapi juga måmbawa pesan...
#
# File: noise_saltpepper_stego_26.png
# Noise Probability: 0.05
# PSNR: 40.77477 dB
# SSIM: 0.43231
# BER: 0.03145
# Similarity: 13.95%
# Levenshtein Distance: 73 | Similarity: 84.57%
# ------------------------------------------------------------
# Batik mesõpakansalah watu#÷Aòisa` budya InooesAa yang memiliki nilai sejarah dan vilosofiàyang sançat inggi  Setiap motof batik tidak ha~y` menghadirkac keindahan visual, 4etapi jg} mel"aa pes`....
#
# File: noise_saltpepper_stego_27.png
# Noise Probability: 0.05
# PSNR: 40.59230 dB
# SSIM: 0.41547
# BER: 0.02669
# Similarity: 5.50%
# Levenshtein Distance: 70 | Similarity: 85.20%
# ------------------------------------------------------------
# Batik meru@akan samáh sapu warisan cõdax! Ihdooesoa ycîg memiliki nilai sejaBah |`. filosofi yang sangat tinggi. Satiap motif batik ti`ak ha~ya menghadirkan keindaha visual, @atapi hqga membawa pesa~...
#
# File: noise_saltpepper_stego_28.png
# Noise Probability: 0.05
# PSNR: 40.86091 dB
# SSIM: 0.49125
# BER: 0.02881
# Similarity: 15.22%
# Levenshtein Distance: 73 | Similarity: 84.57%
# ------------------------------------------------------------
# otif batik tidak hanya menghadirkan Ceondahan visual, tetapi juga meobawa ~%son...ovi yaoç saFgattinggi. Setiapà
#
# File: noise_saltpepper_stego_29.png
# Noise Probability: 0.05
# PSNR: 40.68467 dB
# SSIM: 0.54864
# BER: 0.02458
# Similarity: 19.03%
# Levenshtein Distance: 58 | Similarity: 87.74%
# ------------------------------------------------------------
# Batik meòupakan salah satu warisan8bäax! Ihdonesia yang memilaké nilai sejarah dan filosofi yalg sangat pi|gg® Setiap mo`igàbaik tidak hanya menhatirkan keindahan visual, Detapi jqga membaqa pesan...
#
# File: noise_saltpepper_stego_3.png
# Noise Probability: 0.05
# PSNR: 40.89640 dB
# SSIM: 0.69300
# BER: 0.02008
# Similarity: 20.30%
# Levenshtein Distance: 47 | Similarity: 90.06%
# ------------------------------------------------------------
# enghadipkan keindahan visual, tetapi juga membawa p%saî...emiliki nilai sejapah dan<ilosofi yang sangat tinggi. Setiap motif batik tidak hanya<
#
# File: noise_saltpepper_stego_30.png
# Noise Probability: 0.05
# PSNR: 40.93597 dB
# SSIM: 0.67328
# BER: 0.02881
# Similarity: 31.08%
# Levenshtein Distance: 71 | Similarity: 84.99%
# ------------------------------------------------------------
# Bath+ merupakan saah satu warisan buxay` Indonesia yang memi|iki nilah sejqrah dan fil{ofi x!ng sangat tiîggi. Setiap motif bAti{tidakanya oengha`irkan keiFdahan visual, tetgp	 juga membav! peao...
#
# File: noise_saltpepper_stego_31.png
# Noise Probability: 0.05
# PSNR: 41.01091 dB
# SSIM: 0.58547
# BER: 0.02114
# Similarity: 26.32%
# Levenshtein Distance: 60 | Similarity: 87.42%
# ------------------------------------------------------------
# Bytik merupakan salah/ó`tu warisan buäaya Inäonesia yang a}mihiki nilai sejarah dan fylosïfo yang sangat tilggi. Setiap motif batik tidp+ hanya menghadirkan keindahan ~isual, tetai juga membawa pgsán...
#
# File: noise_saltpepper_stego_32.png
# Noise Probability: 0.05
# PSNR: 41.26128 dB
# SSIM: 0.43811
# BER: 0.02246
# Similarity: 40.21%
# Levenshtein Distance: 60 | Similarity: 87.42%
# ------------------------------------------------------------
# Batië merupakan salah satu warisan bugya Indoner)á yang memh,iki nilai sejarah dan filosofi yang cangaô tonggi. Setiap moif batik tidak hanyaàmenghairkan k|indahan biswál, watapi jug} membaapesan...
#
# File: noise_saltpepper_stego_33.png
# Noise Probability: 0.05
# PSNR: 41.07193 dB
# SSIM: 0.61190
# BER: 0.02643
# Similarity: 4.44%
# Levenshtein Distance: 68 | Similarity: 85.62%
# ------------------------------------------------------------
# aik meòu@akan salah satp warisan budaya H>donesia yang memiliki nhlai sekáòah dan filosofA yang saogqt tinggi. _etiap moôif batik tidakhanya menghatirk`n keindahá~ ~iCuol, tepapi juga Eemâawa pesan...
#
# File: noise_saltpepper_stego_34.png
# Noise Probability: 0.05
# PSNR: 41.43424 dB
# SSIM: 0.78905
# BER: 0.02378
# Similarity: 32.35%
# Levenshtein Distance: 58 | Similarity: 87.74%
# ------------------------------------------------------------
# Batik merupakan salah s}tu warisan bud}ya 	ndonesia yang memioéki nilai sejrah dan fylosofi yana sangat tingçi. Set}ap mowéFbatik tidak hanya mgnghadirkankeindah`nvisu`,, tet!p	 jugá membawa pesan...
#
# File: noise_saltpepper_stego_35.png
# Noise Probability: 0.05
# PSNR: 41.86093 dB
# SSIM: 0.59098
# BER: 0.01903
# Similarity: 58.99%
# Levenshtein Distance: 50 | Similarity: 89.43%
# ------------------------------------------------------------
# Batik }eòpakapsalahsatu warisan budaya Indonesia yang memiDiki nioái sejarah da~ folsofi yang sangat tinggi. Sotiap motyf batik tidak hanya meghadiran heindahan visual, tetapi juga membawá pesao...
#
# File: noise_saltpepper_stego_36.png
# Noise Probability: 0.05
# PSNR: 42.05396 dB
# SSIM: 0.43781
# BER: 0.03198
# Similarity: 7.61%
# Levenshtein Distance: 81 | Similarity: 82.88%
# ------------------------------------------------------------
# Batok merup`kan salah satwàwarisan bqdaya Indongóia y`ng l%oÿliki niloi qejawah dao filn3ofi yag ançat uébggh Sewiqp motig ba`ik tydaC hanya aenohadirkan Ceindahan isual, tetapi jug membawa pesan...
# noise_saltpepper_stego_37.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.05
# PSNR: 40.77216 dB
# SSIM: 0.64702
# noise_saltpepper_stego_38.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.05
# PSNR: 40.83932 dB
# SSIM: 0.43144
#
# File: noise_saltpepper_stego_39.png
# Noise Probability: 0.05
# PSNR: 40.79244 dB
# SSIM: 0.48480
# BER: 0.02828
# Similarity: 15.64%
# Levenshtein Distance: 62 | Similarity: 86.89%
# ------------------------------------------------------------
# Batikmerupakan Calah satu wárisán budaya Indohesia yang aemili{i niìai sejarh dan fioïsofi yang sançat tinggi. Petiap motifàbatik tidakhanya me~gh`dirkan keindahan visual, tetapi ~ga membawa<pesan...
#
# File: noise_saltpepper_stego_4.png
# Noise Probability: 0.05
# PSNR: 41.55173 dB
# SSIM: 0.80276
# BER: 0.01929
# Similarity: 38.90%
# Levenshtein Distance: 49 | Similarity: 89.64%
# ------------------------------------------------------------
# Ba`ik a`rupakan sal`h satu warisan budáyá#Éndonesha yang memiliki~ilai sejara` dan filosofi yang sangat<tinggi. Setiap motif batik uédok hanya menghadirkan keindahcî visaal, tetaph jga oemBawa pesan...
#
# File: noise_saltpepper_stego_40.png
# Noise Probability: 0.05
# PSNR: 41.42501 dB
# SSIM: 0.66059
# BER: 0.02378
# Similarity: 13.32%
# Levenshtein Distance: 59 | Similarity: 87.53%
# ------------------------------------------------------------
# BatiÃ merupaka salah 3atu warisan buda	a Indonesia yang oemilaki nilai qejaráh da~ filosoni yang sangt tynggé  Setiap motif bataë tidak hanyg menghadirkAn keindaèan visual, tgôapi juga membawaàpesan...
#
# File: noise_saltpepper_stego_41.png
# Noise Probability: 0.05
# PSNR: 40.69484 dB
# SSIM: 0.47165
# BER: 0.02669
# Similarity: 6.98%
# Levenshtein Distance: 66 | Similarity: 86.05%
# ------------------------------------------------------------
# Batik merupakan salah satu wArisan cõdáya Indo~esia yaoç memiliki nili sejr}h dan filosofiãùáng songot tinggi. Se|iap motif cátik tidak hanyam}lghadipkan k}inäahan vistal, tdtapi kõga membawa pesan...
#
# File: noise_saltpepper_stego_42.png
# Noise Probability: 0.05
# PSNR: 41.08964 dB
# SSIM: 0.73988
# BER: 0.01903
# Similarity: 18.60%
# Levenshtein Distance: 47 | Similarity: 90.06%
# ------------------------------------------------------------
# Batik merupakan salaè satu wArisa~ budaya Indonesia yng memiliai nilaosejaòah dan filslfi yang s.gat tinggi. Setiap moti~ batik tidaë hanya menghadirkan keihdahcî visual  tetapi juga måmbawa pesan...
#
# File: noise_saltpepper_stego_43.png
# Noise Probability: 0.05
# PSNR: 40.94425 dB
# SSIM: 0.77653
# BER: 0.02246
# Similarity: 5.56%
# Levenshtein Distance: 14377 | Similarity: 2.92%
# ------------------------------------------------------------
# ratik merpakan salgh satu warisan budaya Indonesiapyang memiliki nilai sejarah dFfilosofi yang sangat tinggi. Setiap<mo`if baôik tidk hanya melghdirkan keingáhan viswál, tetgpi juga mem`awa pesan...
#
# File: noise_saltpepper_stego_44.png
# Noise Probability: 0.05
# PSNR: 40.71488 dB
# SSIM: 0.46891
# BER: 0.01771
# Similarity: 28.33%
# Levenshtein Distance: 45 | Similarity: 90.49%
# ------------------------------------------------------------
# Batik meruxkan salgh satu warisan bugaya Indonesia 9ang m`miliqi nilai sejarh dan filosofi yang sangat tibggi. Sewhap#íotif batik tidok hanya menghcäirka keindahan visuol, tet!pi juga membaa pesan...
#
# File: noise_saltpepper_stego_45.png
# Noise Probability: 0.05
# PSNR: 41.46622 dB
# SSIM: 0.69019
# BER: 0.02141
# Similarity: 16.07%
# Levenshtein Distance: 51 | Similarity: 89.22%
# ------------------------------------------------------------
# Bati{ mepupakan salah satu warisan budaya#Éndonesi} yang mgmiliki ~ilai ejarah dan filosofi yang'anat tinf'i. Setéap mïtif natik tidak han! menghairaan keindahan tosual, tetapi juça membawa qåsan...
#
# File: noise_saltpepper_stego_46.png
# Noise Probability: 0.05
# PSNR: 41.02585 dB
# SSIM: 0.65862
# BER: 0.02907
# Similarity: 32.77%
# Levenshtein Distance: 68 | Similarity: 85.62%
# ------------------------------------------------------------
# Batik m`rupakan salah 3atu warisan budaya Ihdongóia yang memyliki nilah sejazah'dan filosofi yang sangat ti~ggi. Sethap motif batik ~Ada{ hanya menahadirkao keingáhan vistal, tetapi jqga hgbawa pesan...
#
# File: noise_saltpepper_stego_47.png
# Noise Probability: 0.05
# PSNR: 41.06159 dB
# SSIM: 0.69403
# BER: 0.02273
# Similarity: 39.96%
# Levenshtein Distance: 51 | Similarity: 89.22%
# ------------------------------------------------------------
# Bat	k merupakab sálah satu warisan budaya Indonesia yang oemiliki nilai sejar}h daî fhlosofi yaoç sa~gat tinggi. Setiap motif batik tidak hanya megh}diroan keindhan ~isul, tgôapi juga memgawa pesan...
#
# File: noise_saltpepper_stego_48.png
# Noise Probability: 0.05
# PSNR: 41.52281 dB
# SSIM: 0.76201
# BER: 0.02035
# Similarity: 45.03%
# Levenshtein Distance: 55 | Similarity: 88.37%
# ------------------------------------------------------------
# Batik mert0akan slah sat5 wariscî budaya Indonesia!ùang mEmh,iki nilai sejarah dan filqsofi yang sangat tinggi. Setiap<mïôif batik tidak hana menhatirkan +eindahan vosual, tetapi juga membawa pesan...
#
# File: noise_saltpepper_stego_49.png
# Noise Probability: 0.05
# PSNR: 40.94620 dB
# SSIM: 0.65867
# BER: 0.02484
# Similarity: 38.27%
# Levenshtein Distance: 53 | Similarity: 88.79%
# ------------------------------------------------------------
# Batik merupaka salah satu warisan8budaya Indonesia Aang memiliki nilaù sejarah dan filosofi yanw sangat tingi. Sotiap motif batik tidak hAnya mebghadirkan keindahan viCual, petapi jua me}bawa pesan...
#
# File: noise_saltpepper_stego_5.png
# Noise Probability: 0.05
# PSNR: 42.07573 dB
# SSIM: 0.70930
# BER: 0.01982
# Similarity: 33.40%
# Levenshtein Distance: 50 | Similarity: 89.43%
# ------------------------------------------------------------
# Bawék<oebt0akan salah satu warisan budaya Indonesia ya`g memiliki nilai såjarah äan filosofi yabg sanaw tynggi. Setiap motif batik uédqk hanya menghadirkal keindahan vosual, tetaði jugc membawa pesan...
#
# File: noise_saltpepper_stego_50.png
# Noise Probability: 0.05
# PSNR: 40.98371 dB
# SSIM: 0.81638
# BER: 0.02881
# Similarity: 11.84%
# Levenshtein Distance: 72 | Similarity: 84.78%
# ------------------------------------------------------------
# o`yf b!tik tiak hanya menohadirkan kdindohan visual tetapi juga me}báwg pesan...F gélosofi yang sngat tinwgi. Sd4iap
#
# File: noise_saltpepper_stego_6.png
# Noise Probability: 0.05
# PSNR: 41.12119 dB
# SSIM: 0.59583
# BER: 0.03330
# Similarity: 13.32%
# Levenshtein Distance: 74 | Similarity: 84.36%
# ------------------------------------------------------------
# ...
#
# File: noise_saltpepper_stego_21.png
# Noise Probability: 0.1
# PSNR: 38.25483 dB
# SSIM: 0.52140
# BER: 0.04281
# Similarity: 2.33%
# Levenshtein Distance: 109 | Similarity: 76.96%
# ------------------------------------------------------------
# @atik }rupa{an pala` satu<qarowán àu|ay` Indoneia yang meíiliki oÁlaisg
# arax danfi|oóofi yang sqng`4 tA~ggi. _epiap l/th& bAt	k tidakànA~ya#íeno@adirkal keindahan visual, tä~api juga embawa pesah...
#
# File: noise_saltpepper_stego_22.png
# Noise Probability: 0.1
# PSNR: 38.15892 dB
# SSIM: 0.30683
# BER: 0.05444
# Similarity: 4.42%
# Levenshtein Distance: 14454 | Similarity: 2.40%
# ------------------------------------------------------------
# Cátik oesõpkan salah sauÅ apisa~ bugcùaàIxdonesi} xang meoélikG ni|ai ekárh da~<filosvi<ya~g s`.g`4uéoæ'k® Setiop mo|if batik podaë hAnya melf(atibkan k	ndahan visuaì, tetapijuga me}bawa ~esqn...
#
# File: noise_saltpepper_stego_23.png
# Noise Probability: 0.1
# PSNR: 37.88318 dB
# SSIM: 0.41038
# BER: 0.05074
# Similarity: 12.68%
# Levenshtein Distance: 106 | Similarity: 77.59%
# ------------------------------------------------------------
# BAtak }eppakán sal!h satu warisan bdáyaàIndoneséa ang memiléki nilai ejara` äan fiìoso`i yAng sangaD tinggiSetiap mhtox batië tyäak hana menghadirkan/ëdondahan visual, tetasé juga membawa es`(...
#
# File: noise_saltpepper_stego_24.png
# Noise Probability: 0.1
# PSNR: 38.58855 dB
# SSIM: 0.58349
# BER: 0.04413
# Similarity: 1.90%
# Levenshtein Distance: 106 | Similarity: 77.59%
# ------------------------------------------------------------
# Batak merupakán salah satuwa~	s}n budaqa IodonesÁáxanG memilëi nAl`9 s}~arh an fiìawofi yang sangatti~ogi.'Stkáð motig bgtik<toak haya mengh`dysëan.keihd`/an8vi{ual, tetaph jug` membawa ~esan...
#
# File: noise_saltpepper_stego_25.png
# Noise Probability: 0.1
# PSNR: 40.16064 dB
# SSIM: 0.68853
# BER: 0.05338
# Similarity: 12.04%
# Levenshtein Distance: 121 | Similarity: 74.47%
# ------------------------------------------------------------
# Âa|ik }rup}ka~ sal satw warh3an budaya Indîesicðyang memioii niao sejarcè dn fil3ofi yyng sangat ~)nggi. óatiap moti` baik thg{ hana mggh`dirkanpkeindahan öiswál,.peapi
# ga hembawa pesah...
#
# File: noise_saltpepper_stego_26.png
# Noise Probability: 0.1
# PSNR: 37.87735 dB
# SSIM: 0.25248
# BER: 0.05180
# Similarity: 10.99%
# Levenshtein Distance: 113 | Similarity: 76.11%
# ------------------------------------------------------------
# Batik måspakáoócíáh spu warisan bu`áya#Éndoneha yang memiliky niln) sejaràh dan filosoni yang sançaô tinggi. Petiqp }otif bytik tida{ hAnyy mgbghcäirkynqëandqha vx;ual, tetapi'~uga me`"awá p`san...
#
# File: noise_saltpepper_stego_27.png
# Noise Probability: 0.1
# PSNR: 37.69518 dB
# SSIM: 0.25296
# BER: 0.05655
# Similarity: 9.09%
# Levenshtein Distance: 137 | Similarity: 71.04%
# ------------------------------------------------------------
# Baikàmgsõwaka slah watu waph3` buäayaàIndonesiá yag l%mh<iki oé|ai sejrh dah vilosofi yano sangatàtinggé. Såwéapàmotif b!tik~idak hGoùaàmena@atiran kgándahan öisun,, teta|y juça mdl"aa pesn...
#
# File: noise_saltpepper_stego_28.png
# Noise Probability: 0.1
# PSNR: 37.96147 dB
# SSIM: 0.35119
# BER: 0.04625
# Similarity: 16.56%
# Levenshtein Distance: 137 | Similarity: 72.87%
# ------------------------------------------------------------
# BatiC mÅbupakapCanyh s`tu wasésan ~udaya IFdn>sia.yag `%mil	{iànilai seêarah dan `iosïfi yang sangat tonggi. Såthap motig batiC ti`ak hanya menghadirkan keiodahan visual, peap	 juga meobawa pesax...
#
# File: noise_saltpepper_stego_29.png
# Noise Probability: 0.1
# PSNR: 37.76824 dB
# SSIM: 0.40761
# BER: 0.04625
# Similarity: 3.79%
# Levenshtein Distance: 110 | Similarity: 76.94%
# ------------------------------------------------------------
# Cátik merupakan sala` sau warisanudayg Aodnesé` yangm`milhoé nioïi sejqrah dan filsogé yangøsanga÷àtinf'h.8Setiap motif bawék tidaë hanya menghadirkan keinda@an isual#ðtåtypi juga hemzawy pEsán...
#
# File: noise_saltpepper_stego_3.png
# Noise Probability: 0.1
# PSNR: 37.95578 dB
# SSIM: 0.53602
# BER: 0.05233
# Similarity: 3.81%
# Levenshtein Distance: 120 | Similarity: 74.63%
# ------------------------------------------------------------
# B`|ok mErupa{an sálah sa~u<warisanbuday@ H.donesï yang måmyh}kiànilai sý~ara`'dan filosofi#ùang cangt uélggi. Setip motyæ natiG tidah<h`nya menghadirkaoð{åoodaxaoàwéwualì tetasùjuga membaw` pesoo...
#
# File: noise_saltpepper_stego_30.png
# Noise Probability: 0.1
# PSNR: 38.04088 dB
# SSIM: 0.50696
# BER: 0.05444
# Similarity: 4.44%
# Levenshtein Distance: 130 | Similarity: 72.52%
# ------------------------------------------------------------
# Bawék meruwakan salahsauõ warisan bugx! IFän.esia.xag mem	oioi oÁüai<se~arah dqn ilosofi yag canc| thnggi. Setiqp motif natiC tidak hanyg me|ghadirkanoeondahýn v`3tal, teuápi jg` måm`wa p%san...
#
# File: noise_saltpepper_stego_31.png
# Noise Probability: 0.1
# PSNR: 38.10120 dB
# SSIM: 0.42047
# BER: 0.04413
# Similarity: 9.51%
# Levenshtein Distance: 106 | Similarity: 77.59%
# ------------------------------------------------------------
# Ba+ mgrupakab sal'h {atu warisan budayG Indoneic yáng memoliki#îilai qejarcè dan iln3ofi yangcangatthnoçk® Set}ap<mhtaf bath( tAdak hanyy meîhadi~kAn ke	ndahan wésual, tetapi juga membawA p%san...
#
# File: noise_saltpepper_stego_32.png
# Noise Probability: 0.1
# PSNR: 38.34558 dB
# SSIM: 0.24779
# BER: 0.04678
# Similarity: 21.99%
# Levenshtein Distance: 103 | Similarity: 78.22%
# ------------------------------------------------------------
# erupaka~ s`la` sa~u wárisan bdaya Indoneia yang memiDii nioñi eê`2}h `a~ filosofi yang angat tonggi. Sewiap mtif batik tidak iáya m`nghánirk`n.k}indaoan visual,~t}tApi ~t?a!íembáwa qåsaî...
#
# File: noise_saltpepper_stego_33.png
# Noise Probability: 0.1
# PSNR: 38.12766 dB
# SSIM: 0.43151
# BER: 0.04783
# Similarity: 18.60%
# Levenshtein Distance: 111 | Similarity: 76.53%
# ------------------------------------------------------------
# Batik mept0akan salah!÷át5 waisan budaya Indnesi` 9cïç memiliki nilai sejarh dan filoscfo yÇng sonat tonggi. Set	qpmotif ba|ik tidak oánya meghatirkankeindahn vasu`,, tetApa jug mambag pean...
#
# File: noise_saltpepper_stego_34.png
# Noise Probability: 0.1
# PSNR: 38.50869 dB
# SSIM: 0.65136
# BER: 0.04493
# Similarity: 4.87%
# Levenshtein Distance: 14425 | Similarity: 2.59%
# ------------------------------------------------------------
# @atik }esõðakab salah 3atu wyr3an'budaya Indonesha yang oemihi{i ny`ai sejaxah'`an f)ïso`i yaoï sangat thngi. Setáp motix bato{àtidakanya mengh`oérkan keindahan vh3ýal/ tt!pi jug|pmmbawà pesn...
#
# File: noise_saltpepper_stego_35.png
# Noise Probability: 0.1
# PSNR: 38.96424 dB
# SSIM: 0.43866
# BER: 0.04545
# Similarity: 0.42%
# Levenshtein Distance: 111 | Similarity: 76.53%
# ------------------------------------------------------------
# eòu@akao 3a|a| satu warisan budaya Ondonesia yang memoDikiànoìai sejarah dan#îiloóofh yyng sa~gat#ôi~ggi  Setéop moth& bgtiè tidak ha~ya menghadirkán kyndahaoÿbisõ`,,!ôetapy juga membawa pesqn...
#
# File: noise_saltpepper_stego_36.png
# Noise Probability: 0.1
# PSNR: 39.14775 dB
# SSIM: 0.26427
# BER: 0.04704
# Similarity: 2.17%
# Levenshtein Distance: 137 | Similarity: 71.04%
# ------------------------------------------------------------
# Batak oerupaoan w~a`!ó`tu waripa~ budayaàx.äonesia yangíelil}ki nilai s`barah dan nilosofi yangàcancát tinggi. SeDiaw ahti~ batik#ðidao hanya mengxayrkan k`i~dahaoç|isual, tåtgðq8juga mel awa peson...
#
# File: noise_saltpepper_stego_37.png
# Noise Probability: 0.1
# PSNR: 37.88415 dB
# SSIM: 0.52081
# BER: 0.05048
# Similarity: 3.25%
# Levenshtein Distance: 137 | Similarity: 71.04%
# ------------------------------------------------------------
# Cátik merp0`aan Ccìah satu wariwan Daya Ihdn/esia xá~g memil}kh nila@ seêráh dan filosofi y`n saÿgop inggi. óewhap motif#âatië<tiak paya m`bwhadirkyn keihdqhaà	sua|, tep`pi8jua membawa pesaF...
#
# File: noise_saltpepper_stego_38.png
# Noise Probability: 0.1
# PSNR: 37.93578 dB
# SSIM: 0.27222
# BER: 0.04440
# Similarity: 1.69%
# Levenshtein Distance: 101 | Similarity: 78.65%
# ------------------------------------------------------------
# eíilikh pilay qearah |aî fi|oslfi yang sangqt pinggi 'Stiax |/tif ba`ik tidaC#ègnyA menghadirkan.keindah}n visual, tetapo jua meobawa pgsao...
#
# File: noise_saltpepper_stego_39.png
# Noise Probability: 0.1
# PSNR: 37.89559 dB
# SSIM: 0.31557
# BER: 0.04625
# Similarity: 0.42%
# Levenshtein Distance: 114 | Similarity: 75.90%
# ------------------------------------------------------------
# `ik mårpak` salaëðs`tuwaripn bu|ayy Ondonesia yang }e}iìikA nil`) sejarah'dan fhlosofi yyng sqngat tinggi. Pethap n/tifbaôik tid`+ hanya meng@adir{a~.oeindahan visu`,, tetai
# g membawa pEsan...
#
# File: noise_saltpepper_stego_4.png
# Noise Probability: 0.1
# PSNR: 38.61675 dB
# SSIM: 0.67961
# BER: 0.04783
# Similarity: 4.44%
# Levenshtein Distance: 117 | Similarity: 75.26%
# ------------------------------------------------------------
# Batakàmesõpakáb slah satw arasa cõd}ya yGdanasya yaoç memiléki<nilai sejarcègán vAlso~iaîg cangap tinggi. Setiop motif batik pAdak hanygàmenghádirkan Ch.d`(an visuaì,teuápi jga -eob÷a pesaè...
#
# File: noise_saltpepper_stego_40.png
# Noise Probability: 0.1
# PSNR: 38.55626 dB
# SSIM: 0.51969
# BER: 0.04757
# Similarity: 0.62%
# Levenshtein Distance: 114783 | Similarity: 0.33%
# ------------------------------------------------------------
# Batyk m}rupákan Calah!ó`u v!òi{an~daya<Indonasia yang memil}ki nilai 'jar`h dan filowoài ygg sqngot tinggi. Set}ap mo÷éf batyk<tidak hanyA l%lohadirkan keindahan öisaaD, tetap	 huGamembawa pesah...
#
# File: noise_saltpepper_stego_41.png
# Noise Probability: 0.1
# PSNR: 37.79419 dB
# SSIM: 0.30697
# BER: 0.05074
# Similarity: 10.99%
# Levenshtein Distance: 121 | Similarity: 74.42%
# ------------------------------------------------------------
# Bgtik merupáoaî pl satu warisa`bu`aya Andnesiá yîg?íemiliki nilai sejar dan fisoæi yang sa~gat i~ogi. _otiap mo`if bGwék tydak xanyá menghadirkan kei~d`(á` vistal< tetapi juga!íembawa ~esan...
#
# File: noise_saltpepper_stego_42.png
# Noise Probability: 0.1
# PSNR: 38.19062 dB
# SSIM: 0.60753
# BER: 0.05523
# Similarity: 4.65%
# Levenshtein Distance: 126 | Similarity: 73.36%
# ------------------------------------------------------------
# Natih me~upakab salah!ó`tu wapisan budaya yndoh}sia yang memili{i nioái sehqrah aF filoson@ ya~ ángat tilGé. Setkáp motifàbatok tidaë hanya aengh`eérkan Ceyndn(a ösual,.ttap	 ~ga membawg qåsán...
#
# File: noise_saltpepper_stego_43.png
# Noise Probability: 0.1
# PSNR: 38.03510 dB
# SSIM: 0.63853
# BER: 0.05127
# Similarity: 11.63%
# Levenshtein Distance: 120 | Similarity: 74.63%
# ------------------------------------------------------------
# Cá`	k l%ruðak`n slah s}tu wa~ipa` budayA#Éndoneqya y}ng meail	ki nilai<sejarah daF filosofh aoç sángat inggi.Setiap moti` cáth tidak hynya mg~gh`dirkac keindahan8visual tet!pi jug} membawa pEóan...
#
# File: noise_saltpepper_stego_44.png
# Noise Probability: 0.1
# PSNR: 37.81249 dB
# SSIM: 0.29044
# BER: 0.03515
# Similarity: 5.57%
# Levenshtein Distance: 271 | Similarity: 42.71%
# ------------------------------------------------------------
# Batok mErupakaï salAh satu warip`n'~q|qa#È.donesha ycîgãem`,ii nioái sejr `an fiìosofi yangààanat thnogi. Setcápümhtif bawék uédak#àanp! mEoïhaeérk`n keiî|`(an v	sual, Deapi jga oemb`wy pesaF...
#
# File: noise_saltpepper_stego_45.png
# Noise Probability: 0.1
# PSNR: 38.53572 dB
# SSIM: 0.53209
# BER: 0.04466
# Similarity: 8.03%
# Levenshtein Distance: 112 | Similarity: 76.32%
# ------------------------------------------------------------
# Ntik a`rt0akan samáh.satu warisan budayaIndonesia yap' memilhki nilai s`êar}`dan ilasofi yano sancat tioçgi. Setiop motifb`tië todak `anx'<menwhadirkal keindahan visual tdtyph ju`} membaqg pesa~...
#
# File: noise_saltpepper_stego_46.png
# Noise Probability: 0.1
# PSNR: 38.10256 dB
# SSIM: 0.48410
# BER: 0.04598
# Similarity: 4.92%
# Levenshtein Distance: 14421 | Similarity: 2.62%
# ------------------------------------------------------------
# bawa pesan...!n wlah sat= warisan buday` Indonesya yang memiléki nilai sejaòah dan filaso`i?ùangangot tinf'i. Setiap motig batik tidaC hanya menghadirkaî oeindhn v	staì, tetypojug` he
# noise_saltpepper_stego_47.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.1
# PSNR: 38.12791 dB
# SSIM: 0.56305
# noise_saltpepper_stego_48.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.1
# PSNR: 38.62422 dB
# SSIM: 0.63142
# noise_saltpepper_stego_49.png: INVALID PAYLOAD (kemungkinan header rusak)
# Noise Probability: 0.1
# PSNR: 37.99268 dB
# SSIM: 0.49088
#
# File: noise_saltpepper_stego_5.png
# Noise Probability: 0.1
# PSNR: 39.17973 dB
# SSIM: 0.56679
# BER: 0.05946
# Similarity: 2.96%
# Levenshtein Distance: 134 | Similarity: 71.67%
# ------------------------------------------------------------
# @`tik#íerupakan sala`!óat5 wariCa ~t$ya Ondonsic Aaoç mgmilaki oélay rjarah danà`hlosofA yá~gàóangaü pinggk® SeDiaw l/ig baôik#idak#anya meìghad(rkyn kgéndaha` vysual  tetaph juga m}mzaw` p}san...
#
# File: noise_saltpepper_stego_50.png
# Noise Probability: 0.1
# PSNR: 38.07743 dB
# SSIM: 0.69062
# BER: 0.04255
# Similarity: 10.36%
# Levenshtein Distance: 106 | Similarity: 77.59%
# ------------------------------------------------------------
# NatiC oerupcëAn 3alah papu waòiwan bugaya Indonesiayngàmemiliky nhlqi r%j`ah daþ filosofy yang saFgat tingi. Seôiap#íotif at	k tidak nynya oenghadirkan kein`ahan v	suah, tetapi
# bawa pesan...
#
# File: noise_saltpepper_stego_6.png
# Noise Probability: 0.1
# PSNR: 38.22178 dB
# SSIM: 0.41682
# BER: 0.04889
# Similarity: 2.33%
# Levenshtein Distance: 116 | Similarity: 75.48%
# ------------------------------------------------------------
# ath+#íerupakan salah satu warisan budaya An|onesia Aáng memiliké oùlai r%cáBax doF filoso~i y`~a8sangat tingçé. Setiax<motyæbatik tidakha~ya meghadirkAn.kei~dhan vasaal, t`t`pi
# uga mdmbawa pesan...
#
# File: noise_saltpepper_stego_7.png
# Noise Probability: 0.1
# PSNR: 38.11573 dB
# SSIM: 0.39410
# BER: 0.04202
# Similarity: 14.59%
# Levenshtein Distance: 106 | Similarity: 77.59%
# ------------------------------------------------------------
# BAtik meòupcëan salah sapu warisap budaya Ind~dsia yang meailii nilai qejarah dan fil{ofi x!ng'sangqt tinggé. Sutiap motyf `Atik tiäak hanyá oengh`diraá~ kåingñhan vióuD, tetapi juga membaa ecan...
#
# File: noise_saltpepper_stego_8.png
# Noise Probability: 0.1
# PSNR: 38.15235 dB
# SSIM: 0.35298
# BER: 0.04704
# Similarity: 7.61%
# Levenshtein Distance: 113 | Similarity: 76.11%
# ------------------------------------------------------------
# Bywék meup}kan salah sau warisan bt$aya IndonesÁa y`ng<mem	lij(#îylao qejaráh dan fAlowofi yang angaw tAnggþ Setiap l/taF ratië tidaC xanq` menghadirj!n keiFgáhan visual, tatapi kõGa membay pesan...
#
# File: noise_saltpepper_stego_9.png
# Noise Probability: 0.1
# PSNR: 37.96180 dB
# SSIM: 0.41531
# BER: 0.04334
# Similarity: 1.69%
# Levenshtein Distance: 107 | Similarity: 77.38%
# ------------------------------------------------------------
# Baôykàmerupaaan salah {}pu aris`oàbudcùa H.donasia yangàmgoéhiki nilai sejarah'dah fisofh yang sangat thnggi. Sutiað motig `at	k#ôidak nalya menghad)rka~ëeandqh}n visual, tetaiàhuga membawa qåsan...
#
# ===== EXTRACTION SUMMARY =====
# Noise Probability = 0.1
# Total images          : 50
# Valid extraction      : 44 (88.00%)
# Invalid payload       : 6 (12.00%)
# Corrupted payload     : 0 (0.00%)
# =================================
#
#
# --- AVERAGE METRICS PER NOISE PROBABILITY ---
# Noise 0.01: {'PSNR': np.float64(48.035920838132036), 'SSIM': np.float64(0.8858844710861069), 'BER': 0.0049495683579985905, 'SeqSim': 67.46731370150775, 'LevDist': 80.33333333333333, 'LevSim': 93.46325249964542, 'ValidPct': 96.0, 'InvalidPct': 4.0, 'CorruptedPct': 0.0}
# Noise 0.05: {'PSNR': np.float64(41.14253496771094), 'SSIM': np.float64(0.6154962446461165), 'BER': 0.023198363820204064, 'SeqSim': 22.121416298917804, 'LevDist': 3503.5434782608695, 'LevSim': 76.17771341965422, 'ValidPct': 92.0, 'InvalidPct': 8.0, 'CorruptedPct': 0.0}
# Noise 0.1: {'PSNR': np.float64(38.23476804544692), 'SSIM': np.float64(0.45997040299175546), 'BER': 0.04667980011531809, 'SeqSim': 6.779992581358604, 'LevDist': 6314.818181818182, 'LevSim': 64.51717093747898, 'ValidPct': 88.0, 'InvalidPct': 12.0, 'CorruptedPct': 0.0}

# %%
import matplotlib.pyplot as plt

valid_probs = []
ber_vals = []
seq_vals = []
lev_vals = []

for prob, metrics in avg_metrics.items():
    if "BER" in metrics:
        valid_probs.append(prob)
        ber_vals.append(metrics["BER"])
        seq_vals.append(metrics["SeqSim"] / 100)  
        lev_vals.append(metrics["LevSim"] / 100) 

plt.figure(figsize=(10, 6))

plt.plot(valid_probs, ber_vals, marker="o", linewidth=2, label="BER")
plt.plot(valid_probs, seq_vals, marker="o", linewidth=2, label="Sequence Similarity")
plt.plot(valid_probs, lev_vals, marker="o", linewidth=2, label="Levenshtein Similarity")

plt.xlabel("Noise Probability")
plt.ylabel("Value")
plt.title("BER, Sequence Similarity, Levenshtein Similarity vs Noise Probability")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
