# %%
import cv2
import numpy as np
import os
from difflib import SequenceMatcher
import Levenshtein

# %%
# Fungsi untuk mengubah bit menjadi text
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

# Fungsi untuk mengubah text menjadi bit
def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# %%
def extract_lsb(image_path):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    # Flatten image
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %%
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 999
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %%
# --- Function to add Salt & Pepper noise ---
def add_salt_pepper_noise(image, prob=0.02):
    noisy = np.copy(image)
    total_pixels = image.shape[0] * image.shape[1]
    num_salt = int(total_pixels * prob / 2)
    num_pepper = int(total_pixels * prob / 2)

    # Salt
    coords = [np.random.randint(0, i - 1, num_salt) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 255

    # Pepper
    coords = [np.random.randint(0, i - 1, num_pepper) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 0

    return noisy

# %%
# --- Batch add noise ---
def batch_add_noise(folder_in, folder_out, prob=0.02):
    os.makedirs(folder_out, exist_ok=True)
    for filename in os.listdir(folder_in):
        if filename.lower().endswith(".png"):
            img = cv2.imread(os.path.join(folder_in, filename))
            noisy = add_salt_pepper_noise(img, prob)
            out_path = os.path.join(folder_out, f"noise_saltpepper_{filename}")
            cv2.imwrite(out_path, noisy)
            print("Noisy version saved:", out_path)

# %%
# --- Bit Error Rate ---
def bit_error_rate(original_text, extracted_text):
    orig_bits = text_to_bits(original_text)
    extr_bits = text_to_bits(extracted_text)

    min_len = min(len(orig_bits), len(extr_bits))
    errors = sum(1 for i in range(min_len) if orig_bits[i] != extr_bits[i])
    total = len(orig_bits)
    return errors / total if total > 0 else 0

# %%
# --- Text Similarity (SequenceMatcher) ---
def text_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio() * 100  # percentage

# %%
# --- Levenshtein Distance ---
def levenshtein_metrics(a, b):
    distance = Levenshtein.distance(a, b)
    max_len = max(len(a), len(b))
    normalized = (1 - distance / max_len) * 100 if max_len > 0 else 100
    return distance, normalized

# %%
# --- Test robustness ---
def test_robustness(stego_folder, noisy_folder, original_message):
    print("\n=== ROBUSTNESS TEST (with Levenshtein) ===")
    for filename in os.listdir(noisy_folder):
        if filename.lower().endswith(".png"):
            noisy_path = os.path.join(noisy_folder, filename)
            ori_name = filename.replace("noise_saltpepper_", "")
            ori_path = os.path.join(stego_folder, ori_name)

            extracted = extract_lsb(noisy_path)

            # --- Metrics ---
            ber = bit_error_rate(original_message, extracted)
            sim_ratio = text_similarity(original_message, extracted)
            lev_dist, lev_sim = levenshtein_metrics(original_message, extracted)

            ori = cv2.imread(ori_path)
            noisy = cv2.imread(noisy_path)
            psnr_val = psnr(ori, noisy)

            # --- Print Proof ---
            print(f"\nFile: {filename}")
            print(f"PSNR: {psnr_val:.2f} dB")
            print(f"Bit Error Rate (BER): {ber:.6f}")
            print(f"Sequence Similarity: {sim_ratio:.2f}%")
            print(f"Levenshtein Distance: {lev_dist} | Similarity: {lev_sim:.2f}%")
            print("Extracted snippet:")
            print("------------------------------------------------------------")
            print(extracted[:200] + "..." if len(extracted) > 200 else extracted)
            print("------------------------------------------------------------\n")

# %%
# --- Run ---
if __name__ == "__main__":
    # 🟡 Original message
    message = (
        "Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. "
        "Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan dan makna yang mendalam. "
        "Motif parang, misalnya, menggambarkan kekuatan, semangat pantang menyerah, serta keberanian dalam menghadapi tantangan hidup. "
        "Sementara itu, motif kawung dipercaya melambangkan kesucian hati dan keinginan manusia untuk mencapai keseimbangan hidup."
    )

    # 🧂 Add noise and test
    batch_add_noise("stego_batik", "noise_saltpepper_batik", prob=0.02)
    test_robustness("stego_batik", "noise_saltpepper_batik", message)
# Out:
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_9.png
#
# === ROBUSTNESS TEST (with Levenshtein) ===
#
# File: noise_saltpepper_stego_1.png
# PSNR: 44.71 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 41.65%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# ratih merupakal 3alah satu warisan budaya Iodonesia yang memilij) nilai sejarah dan filosofi yang sangat tinggi. Setiap ootif batik tidak hanya menghadirkan keindahan visual, tetapi juga me}bawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_10.png
# PSNR: 45.44 dB
# Bit Error Rate (BER): 0.007135
# Sequence Similarity: 68.92%
# Levenshtein Distance: 18 | Similarity: 96.19%
# Extracted snippet:
# ------------------------------------------------------------
# BatiC merupakan salah satu warisan budaya Indonesia yang memilaki nilai sejarah dan filosof) yang sangat tinggi. Setiqp motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa peson...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_11.png
# PSNR: 45.07 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 5.84%
# Levenshtein Distance: 14363 | Similarity: 3.01%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan {alah satu w`risan `udaya Indonesia yang memiliko nilai sejaraiàanàfilosofi yang sangat tinggi. Setiap motif batiC tidakàhanyg menghadirkan keinda@an visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_12.png
# PSNR: 44.72 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 76.83%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indn.esia yang memiliki nilai sejarah dan fiìo{ofi yang sanap tinggi. Setiapàmotif batik tidak hanya menghadirkan kein|ahan visuah, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_13.png
# PSNR: 44.59 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 15.43%
# Levenshtein Distance: 35 | Similarity: 92.60%
# Extracted snippet:
# ------------------------------------------------------------
# yliki nilai sEjarah dan filosogé yáng sangat tinggi. Stiap motifbatik tidak hanx! meoçhadirkan keindahan vistal, tetapi juga meobawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_14.png
# PSNR: 44.79 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 49.47%
# Levenshtein Distance: 30 | Similarity: 93.66%
# Extracted snippet:
# ------------------------------------------------------------
# otif batik tiäaë hanya menghadi~kan keindahan vh3ul, tetapi juga membawa pesan...n filosofi yang saîçat tinggi. Setiap
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_15.png
# PSNR: 45.20 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 75.90%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bud`ya Indonesia yang memilikh nilai sejarah d`. filosofi yang sangat tinggi. Setiapmotif batik tidak hanya meghadirkan keindahan visual, tetapi juga membawa pesa~...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_16.png
# PSNR: 45.19 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 72.09%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meòupcïgn salah satu warisan budaya Indonesia yanG memiliki niìai sejarah dan filosofi yang sngat tinggi. Set	ap motif batik tidak halya menghadirkan keindahanvisual, tetypi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_17.png
# PSNR: 44.99 dB
# Bit Error Rate (BER): 0.013214
# Sequence Similarity: 78.01%
# Levenshtein Distance: 36 | Similarity: 92.39%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mgrupakan salah!óatu warisan budaya Indonesiaycîg memiliki nilai sejarah dan filosofi yang sangat tinggi. Set}ap motif batik tidak haoùa l%nghadirkan keindahan viCual,!ôetapiàjt'a }embawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_18.png
# PSNR: 44.91 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_19.png
# PSNR: 44.95 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 65.33%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# erupakán salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi ang sangat tinggi. Setiap#íotif bath+ tidak hanya menghadirkao keindahan visual, tet`pi juga membawa pean...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_2.png
# PSNR: 44.75 dB
# Bit Error Rate (BER): 0.013478
# Sequence Similarity: 63.00%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# iliki nilai#óejaòah dan filsofi yang sangaD t)nggi. Sethap motif batik<tidak nanya menghadirkan keindahan visual, tetapi juga membawa pesah...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_20.png
# PSNR: 45.61 dB
# Bit Error Rate (BER): 0.006078
# Sequence Similarity: 80.08%
# Levenshtein Distance: 19 | Similarity: 96.01%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah Catu warisan budaya Indonesia yang memiliki nilai sejarah dan f)losofi yangàsangat tinggi. Setiap mo`if batik tidak hanya menghadirkan keiFdahan visual, |etapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_21.png
# PSNR: 45.09 dB
# Bit Error Rate (BER): 0.007664
# Sequence Similarity: 42.92%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah {atu wgri{an budayaIndonesia yang måmiliki nilai sejarah dan filosofi yabg sangaw tinggi. Sethap motif batik tidak hanya menghadirkan keindahan vysual, tetaði juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_22.png
# PSNR: 44.97 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 41.86%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejawah dan filosofi<yang sangat tinggi. Setiap motif bat	k todak hanya menghadirkan kdindahan visual, tetapi juga membawa pesqn...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_23.png
# PSNR: 44.71 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 60.68%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia xang memili{i nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya melghadirkan kåyndahan visual, petapi juga memb`wg pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_24.png
# PSNR: 45.35 dB
# Bit Error Rate (BER): 0.006871
# Sequence Similarity: 84.99%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batyk mEbupakan salah satu warisan budaya Indonesia yang memilkëi nilai sejarah dan filosofy yang sangat tinggi. Sutiap motif batik tidak hanya mengxadisëan keondahan visual, tetaði juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_25.png
# PSNR: 46.89 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 15.43%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Batik<merupakan salah satu warisan bdaya Indonesiayang memiliki nilai s`jarah dan nilosofi yang saîgat tinggi. Setiap motif batik tiak#èanya menghadirkan keindahan vipual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_26.png
# PSNR: 44.71 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 18.18%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mesô0akan salah satu warisan budaya Indonesi} 9ang memh,iki nilai sejarah dan v)losofi yang sangat tinggi.Setiap motif batik tidak iánya menghadirka keingáhanvisual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_27.png
# PSNR: 44.51 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 44.40%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupákan salah satu warisan budaya Indonesia yang memihiki nilai sejarah dan filosofi yangsangat tinggi. Setip ltif batik ué`ak h!nya menghadirkan keihdahan visual, tetaé juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_28.png
# PSNR: 44.78 dB
# Bit Error Rate (BER): 0.006342
# Sequence Similarity: 77.59%
# Levenshtein Distance: 15 | Similarity: 96.83%
# Extracted snippet:
# ------------------------------------------------------------
# ebghadirkan keindahan visual, tetapi jua membawa pesan...gmiliki nilai sejarah dan filosïfi yang sangat tinggi. Setiap motif batik tidak hanya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_29.png
# PSNR: 44.60 dB
# Bit Error Rate (BER): 0.011892
# Sequence Similarity: 1.06%
# Levenshtein Distance: 30 | Similarity: 93.66%
# Extracted snippet:
# ------------------------------------------------------------
# ratik merupakan salah satu qarisan budaya Indoneia xang memiliki nilai sejarcè dan filosofi yang sangat tinggi. Setiap motiæ bAik tidak#èanya menghadirkan keindahan visual, tepapi hu`a mmbawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_3.png
# PSNR: 44.73 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 3.38%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merup}kan salah satu arisan budaya Indonesi` y`ng memiliki niai sejar dan filosofi yang sanat tinggi. Setiap motif batik tidak habya menghadipkan.keindahan visual tetapi juga memzawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_30.png
# PSNR: 44.85 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 8.88%
# Levenshtein Distance: 29 | Similarity: 93.87%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu wgrisan budax! Indonesia yang memiliki nilai sejaran dan#æilosofi yang sangat tinggi. Setia@ motif batik tidak hanaàmenghadhrkan keindahan visaal, tetapi juga hembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_31.png
# PSNR: 44.92 dB
# Bit Error Rate (BER): 0.014799
# Sequence Similarity: 44.19%
# Levenshtein Distance: 30 | Similarity: 93.66%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupa{an salah satu warisan bud}ya Indonesia yan` memiliki nilao sgjar}h dan filosofi yang sangat tinggi. Setiap motif batik tidak hanyy meoç@adirkan keindahan'visual, tetapi ju`a membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_32.png
# PSNR: 45.17 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 13.95%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaoan salah s`tu warisan cõ|aya IhdonesAa y}ng memiliki ilai sejarah dan filosoni yang sangat tinggi  Setiap motif batik tidak hanya menghadir{an keiFdahan visul, tetapi juga membawa esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_33.png
# PSNR: 44.99 dB
# Bit Error Rate (BER): 0.003436
# Sequence Similarity: 16.49%
# Levenshtein Distance: 12 | Similarity: 97.46%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mgrupakan salah satu warisan budaya Indonesia yang memiliki nilai sekárah dan filosofi yang sangat tinggi. Seôiap motif batik tidak hanya mgnghadirkan +eindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_34.png
# PSNR: 45.32 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 68.29%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang }emioiki niloi sejarah dan filosofi yang sangat tinggi. Satiap motif batik tidak hanya menghadirk`n keindahan visual, tetapi juga meabaw` pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_35.png
# PSNR: 45.76 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 22.83%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya IFdonesic yáng memi|iki nilai sejarah dan filosofi yang sangat tiggi. Setiap moti~ batik tidak hanya me~ghadirkao keindahan visual, tetaði juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_36.png
# PSNR: 45.97 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 25.79%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan<filosofi yang sangat<tingGi. Setiap motiæ batik tidak hanya menghaoèrkan keindahan vasual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_37.png
# PSNR: 44.72 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 68.11%
# Levenshtein Distance: 46 | Similarity: 90.27%
# Extracted snippet:
# ------------------------------------------------------------
# Batik m`rupakan salah satu waposan buda	a Indonesia yang memiliki nylai sejarah dan filosofi yyng saîgat tinggé. Setiap motif batik tida{ hanya meng@adirkan keindahan vosual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_38.png
# PSNR: 44.75 dB
# Bit Error Rate (BER): 0.015063
# Sequence Similarity: 40.17%
# Levenshtein Distance: 38 | Similarity: 91.97%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sau warisaoàbud}ya Indonesia yan memiliki nilai s`jarah dao filosofi yang sangat tinggi. Setiap motif batyk tidak hanyamenghadirkan keindahan visual, tetapi juga Eembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_39.png
# PSNR: 44.71 dB
# Bit Error Rate (BER): 0.012949
# Sequence Similarity: 73.78%
# Levenshtein Distance: 29 | Similarity: 93.87%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaaao sa`ghpsatu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak habyá menghadirkan keindahan visuol, tetapi juga!íembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_4.png
# PSNR: 45.56 dB
# Bit Error Rate (BER): 0.007400
# Sequence Similarity: 3.38%
# Levenshtein Distance: 19 | Similarity: 95.98%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merup`kan salah satu#÷arisan budayaIndonesia.yang memiliki nilai sekárah dan filosofi yang sangat tiîggi. Setiap motif bawék tidak hanya menghadirkan keindahan vi{ual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_40.png
# PSNR: 45.35 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 38.69%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# @atik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. etiap motif batik tidak hynya menghadirkan keindaèan visual, tetapiàjuga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_41.png
# PSNR: 44.62 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 45.88%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# enghadirkan keindaèan vysual, tetapi juga membawa pesan...emiliki nilai sejarah dan#æilosofi yang sangat inggi. Setiap motif batik tidak hanya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_42.png
# PSNR: 45.04 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 3.38%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupkan salah satu arisan budaya Indonesia yang memiléki nilai sejarah dan fhlosofi yang sangat tinggi. Setiap motif batik tidak halya menghadirkyn keindahan visual, tetapi juga membawa pesao...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_43.png
# PSNR: 44.83 dB
# Bit Error Rate (BER): 0.009249
# Sequence Similarity: 68.29%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan palah satu waripan budaya Indonesia yang memiliki#îilai sejarah dan filosofi yaîg cangat tAnggi. Seiap motif batik tidak hylya menghadirk`n kdindahan vióual, tetapi juga membawa pesa~...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_44.png
# PSNR: 44.63 dB
# Bit Error Rate (BER): 0.011892
# Sequence Similarity: 62.37%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik me~upakan sa`ah watu waòisan budaya Indonesia yang memiliki nilaisejarah d`. filasofi yang saFgat tinggi. Setiap motif batak tidak hanya menghadirkan keindahan visual, wetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_45.png
# PSNR: 45.35 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 20.93%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indnesia yang memiliki nilai sejarah dan vilosofi yang sangat tinggi. Sethap motif batik tidak hanya menghaeérkán kindahan visual, tetapi jugá membawa pean...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_46.png
# PSNR: 45.00 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 49.05%
# Levenshtein Distance: 27 | Similarity: 94.29%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budayaIîdonesia yang memiliki nilai sejarah dan filosofi yang sangat tiîggi. Sew}ap motif batik tidak hanya menghadirkan keindahan visual, tetapi
# uga membáwa pEao...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_47.png
# PSNR: 44.92 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 27.70%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sat5 warisan'budaya IndoFasia yang memiliki nilaiqejarah don filosofi yang sangat tinggi. Setiap motif batik tidak hanya mEnghadirkan kein|ahan visual  ttApi8juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_48.png
# PSNR: 45.42 dB
# Bit Error Rate (BER): 0.003700
# Sequence Similarity: 87.32%
# Levenshtein Distance: 11 | Similarity: 97.67%
# Extracted snippet:
# ------------------------------------------------------------
# Batië merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_49.png
# PSNR: 44.82 dB
# Bit Error Rate (BER): 0.015592
# Sequence Similarity: 6.77%
# Levenshtein Distance: 34 | Similarity: 92.81%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu÷arisan budaya Indonesia yang memil	ki nil`) sejarah dan filosofi yang sahgat tolggi. Setiapmot`& batik tidak hanya menghadirkan keyndahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_5.png
# PSNR: 45.97 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 65.54%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# B!tik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan viln3ofiàyang sangat tinggi. Setiap motif batik tidak<nanya menghadirkan kein|ahan visual,ptetypi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_50.png
# PSNR: 44.87 dB
# Bit Error Rate (BER): 0.010307
# Sequence Similarity: 9.89%
# Levenshtein Distance: 31 | Similarity: 93.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satp warysan buDaya Indonesia Aang memiliki nilai se
# arah dan fi|sofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahcî isual, t}tapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_6.png
# PSNR: 45.05 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 65.33%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan slah satu warisan budaya Ihdn.eia yang memiliki nilai sejarah dan filo{ofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirj!n keiFdahan vipual, tetapi juga membawa esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_7.png
# PSNR: 44.94 dB
# Bit Error Rate (BER): 0.009249
# Sequence Similarity: 72.52%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia!ùang memiliki nioái sejarah danàfilosof) yang sangat tinggi. Setiap motif batik tidak hanya m}nghadirkankeindahan vi{ual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_8.png
# PSNR: 44.96 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 55.60%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakanpsalah satu warisan budaya Indonesia yang memiliki nilai sejarah dah filsofi yang sangat tinggi. Setiap motif batik tid`+ halya menghadirkan keindahan vi{ual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_9.png
# PSNR: 44.78 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 28.75%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budax! Indnesia yang mgmiliki nilai sejarah dan filosofi yaoç sangat ~inggi. Setiap motif batik#ôidak hanya menghadirkan keind`(an vi{ual, t}tai juga membav! pesah...
# ------------------------------------------------------------
