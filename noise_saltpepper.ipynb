# %%
import cv2
import numpy as np
import os
from difflib import SequenceMatcher
import Levenshtein
import csv

# %%
# Folder to store CSV results
os.makedirs("robustness_results", exist_ok=True)
csv_path = os.path.join("robustness_results", "saltpepper_metrics.csv")

# %%
# Initialize CSV file with headers
with open(csv_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["File", "PSNR (dB)", "BER", "Sequence Similarity (%)", "Levenshtein Distance", "Levenshtein Similarity (%)", "Extracted Snippet"])

# %%
# Fungsi untuk mengubah bit menjadi text
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

# Fungsi untuk mengubah text menjadi bit
def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# %%
def extract_lsb(image_path):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    # Flatten image
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %%
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 999
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %%
# --- Function to add Salt & Pepper noise ---
def add_salt_pepper_noise(image, prob=0.02):
    noisy = np.copy(image)
    total_pixels = image.shape[0] * image.shape[1]
    num_salt = int(total_pixels * prob / 2)
    num_pepper = int(total_pixels * prob / 2)

    # Salt
    coords = [np.random.randint(0, i - 1, num_salt) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 255

    # Pepper
    coords = [np.random.randint(0, i - 1, num_pepper) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 0

    return noisy

# %%
# --- Batch add noise ---
def batch_add_noise(folder_in, folder_out, prob=0.02):
    os.makedirs(folder_out, exist_ok=True)
    for filename in os.listdir(folder_in):
        if filename.lower().endswith(".png"):
            img = cv2.imread(os.path.join(folder_in, filename))
            noisy = add_salt_pepper_noise(img, prob)
            out_path = os.path.join(folder_out, f"noise_saltpepper_{filename}")
            cv2.imwrite(out_path, noisy)
            print("Noisy version saved:", out_path)

# %%
# --- Bit Error Rate ---
def bit_error_rate(original_text, extracted_text):
    orig_bits = text_to_bits(original_text)
    extr_bits = text_to_bits(extracted_text)

    min_len = min(len(orig_bits), len(extr_bits))
    errors = sum(1 for i in range(min_len) if orig_bits[i] != extr_bits[i])
    total = len(orig_bits)
    return errors / total if total > 0 else 0

# %%
# --- Text Similarity (SequenceMatcher) ---
def text_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio() * 100  # percentage

# %%
# --- Levenshtein Distance ---
def levenshtein_metrics(a, b):
    distance = Levenshtein.distance(a, b)
    max_len = max(len(a), len(b))
    normalized = (1 - distance / max_len) * 100 if max_len > 0 else 100
    return distance, normalized

# %%
def test_robustness(stego_folder, noisy_folder, original_message, noise_prob=None):
    """
    Compute metrics for images in noisy_folder, print them, save to CSV, and return averages.
    noise_prob: float, the noise probability to store in CSV
    """
    psnr_list, ber_list, seqsim_list, levdist_list, levsim_list = [], [], [], [], []

    for filename in os.listdir(noisy_folder):
        if filename.lower().endswith(".png"):
            noisy_path = os.path.join(noisy_folder, filename)
            ori_name = filename.replace("noise_saltpepper_", "")
            ori_path = os.path.join(stego_folder, ori_name)

            extracted = extract_lsb(noisy_path)

            # --- Metrics ---
            ber = bit_error_rate(original_message, extracted)
            sim_ratio = text_similarity(original_message, extracted)
            lev_dist, lev_sim = levenshtein_metrics(original_message, extracted)

            ori = cv2.imread(ori_path)
            noisy = cv2.imread(noisy_path)
            psnr_val = psnr(ori, noisy)

            # --- Print Proof (unchanged) ---
            print(f"\nFile: {filename}")
            print(f"PSNR: {psnr_val:.2f} dB")
            print(f"Bit Error Rate (BER): {ber:.6f}")
            print(f"Sequence Similarity: {sim_ratio:.2f}%")
            print(f"Levenshtein Distance: {lev_dist} | Similarity: {lev_sim:.2f}%")
            print("Extracted snippet:")
            print("------------------------------------------------------------")
            print(extracted[:200] + "..." if len(extracted) > 200 else extracted)
            print("------------------------------------------------------------\n")

            # --- Save to CSV with Noise Probability ---
            snippet = extracted[:200] + "..." if len(extracted) > 200 else extracted
            with open(csv_path, mode="a", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow([
                    filename,
                    noise_prob if noise_prob is not None else "",
                    f"{psnr_val:.2f}",
                    f"{ber:.6f}",
                    f"{sim_ratio:.2f}",
                    lev_dist,
                    f"{lev_sim:.2f}",
                    snippet
                ])

            # --- Store metrics for averaging ---
            psnr_list.append(psnr_val)
            ber_list.append(ber)
            seqsim_list.append(sim_ratio)
            levdist_list.append(lev_dist)
            levsim_list.append(lev_sim)

    # --- Compute averages ---
    num_files = len(psnr_list)
    if num_files > 0:
        return {
            "PSNR": sum(psnr_list)/num_files,
            "BER": sum(ber_list)/num_files,
            "SeqSim": sum(seqsim_list)/num_files,
            "LevDist": sum(levdist_list)/num_files,
            "LevSim": sum(levsim_list)/num_files
        }
    else:
        return None

# %%
# --- Run ---
if __name__ == "__main__":
    # Original message
    message = (
        "Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. "
        "Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan dan makna yang mendalam. "
        "Motif parang, misalnya, menggambarkan kekuatan, semangat pantang menyerah, serta keberanian dalam menghadapi tantangan hidup. "
        "Sementara itu, motif kawung dipercaya melambangkan kesucian hati dan keinginan manusia untuk mencapai keseimbangan hidup."
    )

    # Add noise and test
    noise_probs = [0.02, 0.05, 0.1]
    avg_metrics = {}

    for prob in noise_probs:
        folder = f"noise_saltpepper_batik_{prob}"
        batch_add_noise("stego_batik", folder, prob)
        avg_metrics[prob] = test_robustness("stego_batik", folder, message, noise_prob=prob)
    
    print("\n--- AVERAGE METRICS PER NOISE PROBABILITY ---")
    for prob, metrics in avg_metrics.items():
        print(f"Noise {prob}: {metrics}")
# Out:
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik_0.02\noise_saltpepper_stego_9.png
#
# File: noise_saltpepper_stego_1.png
# PSNR: 44.68 dB
# Bit Error Rate (BER): 0.006871
# Sequence Similarity: 16.23%
# Levenshtein Distance: 21 | Similarity: 95.59%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sau warisan budaya Inäonesia yang memiliki nilao sejarah dan filoso`i yang sangat tinggi. Setiap motifcá`ik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_10.png
# PSNR: 45.50 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 20.08%
# Levenshtein Distance: 27 | Similarity: 94.29%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bu|aya Indonesia yang mgmiliki ~ilai sejaBah dan nioïsofi yang sangat tinggi. óotiap motif batik idak hanya menghadirkAn keindahan visual, teapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_11.png
# PSNR: 45.06 dB
# Bit Error Rate (BER): 0.007135
# Sequence Similarity: 62.16%
# Levenshtein Distance: 19 | Similarity: 95.98%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaan salah satu warisan budaya Indonesia yang memiìiki nilai sejarah dan filosofi yang sangat tinggi. Sethap mo`if batik tidak hanya menghadirkan keindahan visual, tetapi jga måmbawa peóan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_12.png
# PSNR: 44.72 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 74.42%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisn budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya mengxaeérkan keiodaha visual, tetapi
# ug membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_13.png
# PSNR: 44.61 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 69.98%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bdaya Indonesia yan' memihiki nilai s}jarah dan filosofi yang sangat tinggi. Såtiap motif batik tidak hanya menghadiòkan keinahan visual, tetapi juga membwa peson...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_14.png
# PSNR: 44.76 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 5.92%
# Levenshtein Distance: 28 | Similarity: 94.08%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah s}tu#÷arisan budaya IndonesAa ya`g memiliki nilai sejarah dan#æAlosofi yang8sangat uénggi. Setiap motif batik tida{ hanya menghairkan +eindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_15.png
# PSNR: 45.20 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_16.png
# PSNR: 45.20 dB
# Bit Error Rate (BER): 0.011892
# Sequence Similarity: 13.11%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik me~upakan salak®patu warisan bu`aya Indonesia yang memiliki nilai se
# arah dan filosofi yang sangat tingh. Setiap motif batik tidak#èanya menghairkan keindahan viCul, teta`i juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_17.png
# PSNR: 44.98 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 22.20%
# Levenshtein Distance: 30 | Similarity: 93.66%
# Extracted snippet:
# ------------------------------------------------------------
# Bawék merupakan salah satu warisan budaya Indonesia yang memiliké nilao sejarah dan filosofi yang sangat tinggi. otiap motif ba`ik tidak hanya mengxadirkan keindahaoàvisual, tgôaði juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_18.png
# PSNR: 44.91 dB
# Bit Error Rate (BER): 0.013742
# Sequence Similarity: 55.39%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budáya 	ndonesia yang memiliki nilai sejarah dan filosofi yang angat tinggi. Setiap<moôif<batik tydak?è!nyamenghádirkan keindahan visuaì, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_19.png
# PSNR: 44.91 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 50.74%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakal!óalah satu warisan budaya Indonesia y}ng memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik ti|ak hanya menghadirkan keindahan viwuah, tgôapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_2.png
# PSNR: 44.76 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_20.png
# PSNR: 45.59 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 75.90%
# Levenshtein Distance: 19 | Similarity: 95.98%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mesõpakan salah satu warisan budaya 	ndonesia yang memiliki nilai<sejarah dan filosofi yang sangat tinggi. Setiap motif batik<tidak hanya aenghadirkan keindahan visal, tetapi juga membawa peóan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_21.png
# PSNR: 45.07 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 76.96%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Bgtië merupakan salah.Capu warisan budaya I~donesia yang memiliki nilai sejazah dan filosofi yang sangat tinggi. Setiap motif bg|ik tidak hAnya menghadirkan keindahan visuao, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_22.png
# PSNR: 44.98 dB
# Bit Error Rate (BER): 0.011099
# Sequence Similarity: 19.03%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah!óauõ warisa` budaya Indnesia yang memiliki ~)lai sejorah dan filoóofi yang sangat tioçgi Setiap motif batik tidak hanya mengh}dirkan keindahan viwual, tetapi juga mel"aqa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_23.png
# PSNR: 44.70 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 48.84%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sátu wari{an budaya In`onesia yang memil}ki nilai sejar}h dan filasofiyang sangat tinggi. Setiap motif batik tidak hanyA menghadirkAn keindahaoàvysual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_24.png
# PSNR: 45.29 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 65.96%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu war	san budaya Indonesia xang memilkëi nilai sejarah dan filosofi yang sangat tinggi. Swiap mhtif batik tidak hany` menghadirkan keindahan visual, tetapi jça memgawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_25.png
# PSNR: 47.04 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 34.88%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan8budaya Indonåsia yang mem	liky nilai sejarcè dan filosofi yang'sangat tinggi. Setiap motif batik tidak hanya menghadipj!nk}indahan visual, tetapi juga membaa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_26.png
# PSNR: 44.72 dB
# Bit Error Rate (BER): 0.007400
# Sequence Similarity: 74.21%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# B`tik merupakan salah satu warisa~ budaya Indonesia yang memihiki nilai sejarah dan filosofi yang sangat t)nggi. Setiap motif batik tidak hanya menghadyrkanpkeindahan visual, tetai juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_27.png
# PSNR: 44.53 dB
# Bit Error Rate (BER): 0.006607
# Sequence Similarity: 44.19%
# Levenshtein Distance: 18 | Similarity: 96.19%
# Extracted snippet:
# ------------------------------------------------------------
# BgtiC merupakal salah satu warisan budaya Indonesia yang memiliki nilai sejarah danàfilosofi yang sangat tinggi. Setiap motif batio tidak hanya oenghadirkan keindaha visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_28.png
# PSNR: 44.76 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 20.93%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan s`lah sat}#÷arisan budaya Indoner)a yang mgmiDiki nilai sejqrah dan filosofi yang sangat tinggi Setiap motif batik tydak hanya menghadirkan keindahan visual, tetapi juga membawapesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_29.png
# PSNR: 44.57 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 10.57%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu waris}n budaya Indondsia yang memiliki nilai sebarah dan filosofi yang sahgat tinggi. Setiap motif batik tidak hanyg menghadirkankeindahan viCual, tetapiàjuga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_3.png
# PSNR: 44.81 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 20.51%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# Batik l%rupkan sal satu warisan budaya Indonesia yang mgmiliki nilai sejarah dan filosofi ya~f sangt tinggi. etiap motiæ batik tidak hanya menghadiran kind`(an v	su`,,.tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_30.png
# PSNR: 44.86 dB
# Bit Error Rate (BER): 0.011628
# Sequence Similarity: 22.29%
# Levenshtein Distance: 59 | Similarity: 88.32%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan s}lah satu wa~isan budaya Ixdonesia yang memiliki nilai sejaòah dan filosofi yaoç paîgat thnggi. tiap moti` batik tidak hanya menghadirkan keindahan vi{ual, tetapi8juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_31.png
# PSNR: 44.93 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 14.96%
# Levenshtein Distance: 22 | Similarity: 95.38%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya I~onesia yang memiliki nilai ejarah dan vilasofi yang sangat inggi. etiap motif batikôidak hanya menghadirkan keindahan visual, tetapi jug membawa#ðesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_32.png
# PSNR: 45.16 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 21.99%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mebuðakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi 	ang sangaw tinggk® Setiap motif batik tidak hanya menghadirkan keindahaoàvisual, tetasé juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_33.png
# PSNR: 44.94 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 38.27%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupcëan salah satu warisan buäaya Indonesia yang<memiliki nilai s`jarah dan filopofA yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan oei~dahan visual, tetapi jga membawa pes`(...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_34.png
# PSNR: 45.30 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 19.66%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan {alah satu warisan budaya Indonesia yang memiliki nilai sejar}h dan#æilo{ofi yang sangat ~inggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_35.png
# PSNR: 45.78 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 53.49%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satE warisan budaya Inäonesia yang l%miliki nilai sejazah dan filosofA yag8sangat thnggi. Setiap motif bawék tidak hanya menghadirkan keh.dahan vh3ual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_36.png
# PSNR: 45.97 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_37.png
# PSNR: 44.70 dB
# Bit Error Rate (BER): 0.012685
# Sequence Similarity: 18.82%
# Levenshtein Distance: 29 | Similarity: 93.87%
# Extracted snippet:
# ------------------------------------------------------------
# Natio merupakan salah satu wari{an budaya Indonesia yang memiliki nilai sejarah dan viìosofA yalg sangat tingi. Setiap motif b!tik tidak hanya menghadirkan keindahn visual, tetap	 juga membawá<pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_38.png
# PSNR: 44.76 dB
# Bit Error Rate (BER): 0.010307
# Sequence Similarity: 46.72%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaoan salyh satu w`risan budaya Indonesia yang memyliki nilay sejarah dah filosofi yanf sangat tynggi. Setiap l/tif batiktidak hanya menghadirkan keindah`n visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_39.png
# PSNR: 44.69 dB
# Bit Error Rate (BER): 0.015063
# Sequence Similarity: 25.16%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosof) yang sangat tinggi. Cetiap motif bat	k tidk hanya menghadirkan keindhan visual teapa juga måmbawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_4.png
# PSNR: 45.40 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 73.78%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meruxakan salah sátu warisan budaya Ihdonsia yang memiliki nilai sejarah don filosofi yang óangat tinggi.'Suti`0 motif batik tidk hanya menghadirkan keindahan visual, tetaði juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_40.png
# PSNR: 45.40 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 41.44%
# Levenshtein Distance: 28 | Similarity: 94.08%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan sal!h satu warisan budaya Indonesia ya`g memiléoi nilai sejarah dan filosofi yang sangat tinggi. Setiap moif batië tidak hanyamebghadirkan keindahan visual, tetapi jua membawa pesqn...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_41.png
# PSNR: 44.62 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 10.15%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah!óatu warisan budaya Indoîesia yang memiliki nilai seharah äaF filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghanirkan keindahan visual, tatapi juga Eembawa ~esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_42.png
# PSNR: 45.01 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 20.93%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Baôik merupakan salah satu warisan budaya Indonesia yang memil}ki nilai sejarah dan ilosofi yAng sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membc÷a pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_43.png
# PSNR: 44.84 dB
# Bit Error Rate (BER): 0.004757
# Sequence Similarity: 72.09%
# Levenshtein Distance: 14 | Similarity: 97.04%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nAlai sejarah dan filosofi yang sança| ti~ggi. Setiap motif batik tidak hgnya mEnghadirkan keindahán visual, tetapi juga mem`awa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_44.png
# PSNR: 44.63 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 7.61%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# B`tik mEruwakan salah satu waripan budaya Indonesia yang memioiki#îilai sekárah dan filosofi yang sangat tinggi. Setiap motifàbatik tidaC hanya menahadirkan +eindahan visual, tetapi juga memzawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_45.png
# PSNR: 45.38 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 57.72%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salahpsatu warisan budaya Indonesya yang memiliki nilai r%jaraiàdan filosofA yangàsangat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visuah, ttapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_46.png
# PSNR: 44.90 dB
# Bit Error Rate (BER): 0.006342
# Sequence Similarity: 13.11%
# Levenshtein Distance: 16 | Similarity: 96.62%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merpakan salah satu warisan budaya Indonesia yang meliliki nilai seharah dan filosof) y`g songat tinggi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_47.png
# PSNR: 44.90 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 69.98%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaj!n salah satu warisan budaya Indonesia yang memilij) nilai sejaran dan filsofi yang sangaw tinggi. Setiap motif batih tidak hanya menghadipkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_48.png
# PSNR: 45.43 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 20.93%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan slah satu warisan budaya Indonesic yang memiliki nilai sejarah dan filoCofi ygng sangat tingga. óetiap motif batak tidak hgnx! menghadirkan keindahan visualì tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_49.png
# PSNR: 44.82 dB
# Bit Error Rate (BER): 0.007664
# Sequence Similarity: 63.00%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik l%rupakan salah satu warysan budaya Indonesia yang memiliki nilai sejarah dan filosofh yang sangaô tinggi. Setiap motif bytik tidak hanya mEnghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_5.png
# PSNR: 46.02 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 34.67%
# Levenshtein Distance: 17 | Similarity: 96.41%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satp warisan budaya IndoFesia yang memiliki ilai sejarah dan filosofi yang sangat tinggi. Stiap motif batik tidak hanya menghadArka~ Ceindahan visual, tetapi juga membav! pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_50.png
# PSNR: 44.87 dB
# Bit Error Rate (BER): 0.013214
# Sequence Similarity: 60.47%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu waisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yanf songat tinggi. Setiap motif ratik tidak hanya menghadirkanpkeindahoàvisual, tetapi juga }embawa ~esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_6.png
# PSNR: 45.06 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 66.38%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaka salah satu arisanbudaya Indn.esia yang memiliki nilai sejarah dan filosofi ang sangat tinggi. Setiap motif batak tidak hanya m`nghadirkan keindahan ~isual,tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_7.png
# PSNR: 44.92 dB
# Bit Error Rate (BER): 0.010042
# Sequence Similarity: 69.34%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mesõpakAn salah satu warisan ~uda	a Indonesia xang mgmiliki nilai sejarah dan filosofi yang cangat tinggi. Setiap motif batik tidqk nanya menohadirkan keindhan visuaï, tetapi jugapmembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_8.png
# PSNR: 44.99 dB
# Bit Error Rate (BER): 0.007400
# Sequence Similarity: 72.73%
# Levenshtein Distance: 18 | Similarity: 96.19%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan saah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filoscfi yang sangat tinggi. Setiap motif batik todak haya menghadirkan keindahan visual, tepapi jug membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_9.png
# PSNR: 44.78 dB
# Bit Error Rate (BER): 0.013742
# Sequence Similarity: 13.95%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik me~upaan salah satu warisan budayg Inonesia yang memiliki nilai ejarah dan filosoni<yang8sangat tinggé. Setiap motif batik tidak hynya menghadirkan keindahan visual, tetypi juga memâawa pean...
# ------------------------------------------------------------
#
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik_0.05\noise_saltpepper_stego_9.png
#
# File: noise_saltpepper_stego_1.png
# PSNR: 40.77 dB
# Bit Error Rate (BER): 0.019027
# Sequence Similarity: 22.83%
# Levenshtein Distance: 46 | Similarity: 90.27%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupáka salah satu warisan budaya ndonesia yang me}iliki nioái s`jaB}h dan filosofi x!ng sangat tioçgh. Setiap<motif batiC tidakàhanyy menghadika~ keinda@an visual, tetapi juga memzawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_10.png
# PSNR: 41.68 dB
# Bit Error Rate (BER): 0.027220
# Sequence Similarity: 3.59%
# Levenshtein Distance: 60 | Similarity: 87.32%
# Extracted snippet:
# ------------------------------------------------------------
# B`tio merupak`o salah wau warisa` ~udayaàIndonesia ya`g memioiki nilai sejarah dan filoCofiyang cangat tinggi  Sutiap motif batik tigák haya menghadirkan keindahan v	stal, wetasé èuga memgawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_11.png
# PSNR: 41.14 dB
# Bit Error Rate (BER): 0.028805
# Sequence Similarity: 30.06%
# Levenshtein Distance: 1601 | Similarity: 20.31%
# Extracted snippet:
# ------------------------------------------------------------
# Batih merupakan sálah s}pu warisan budya Ondonesia yang memilhkiànilai sejarah dan filosofi yang sangat tAlgçi. Satkáp motif batik#ôidqh ha~ya menghadirkan keindaha tisual tetapi jug` membwa#ðesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_12.png
# PSNR: 40.80 dB
# Bit Error Rate (BER): 0.024577
# Sequence Similarity: 1.06%
# Levenshtein Distance: 61 | Similarity: 87.10%
# Extracted snippet:
# ------------------------------------------------------------
# engxadirkan kiodahan visual, tetapi juga membawa pesan...iap mGtiæ batië#ôidak<hanya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_13.png
# PSNR: 40.71 dB
# Bit Error Rate (BER): 0.024841
# Sequence Similarity: 12.26%
# Levenshtein Distance: 62 | Similarity: 86.89%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meóõpaj!n salah s}tu warisan budaya Indonesia ya~g memylikA nilah sejarh dan ilosofi yAng sangat tilg`i. Setiap mo|if batik tidak hanya menghadipkan keind`(anvisual, tetapi'jga memzaa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_14.png
# PSNR: 40.85 dB
# Bit Error Rate (BER): 0.021934
# Sequence Similarity: 44.61%
# Levenshtein Distance: 52 | Similarity: 89.01%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meupaka salahpsatu warisan budaya Indonesia yang memilii nhlai sejarah dan filosfi yang'sqngat ~inagi. Setiað mGtifàbatik tidakhan	a me~ghadirkyn!ëeindahan bi{un,, 4etapi juga mmbawg pean...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_15.png
# PSNR: 41.28 dB
# Bit Error Rate (BER): 0.023520
# Sequence Similarity: 39.96%
# Levenshtein Distance: 57 | Similarity: 87.95%
# Extracted snippet:
# ------------------------------------------------------------
# Batik m`rupakanpsa|xh Catu warióan bt$aya H.donesia yang memiliki niai sejarah äan fAlosofA yabg sanga| tinggi. Seôiap moth& batik tidak hanya menghadirkyn oeindahán visuol, Detapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_16.png
# PSNR: 41.28 dB
# Bit Error Rate (BER): 0.023520
# Sequence Similarity: 15.22%
# Levenshtein Distance: 59 | Similarity: 87.53%
# Extracted snippet:
# ------------------------------------------------------------
# Cátik merup`k`o s`lah sau waòisan budaya Indonesia ycîg m}moliki nilaiàsejn2ah da~ filosofi yang sangat tinggi/àSetiap motif batik ti|ak hanya melghadirkan keindahan visual, t}tapi juga hem`awa qåsan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_17.png
# PSNR: 41.12 dB
# Bit Error Rate (BER): 0.019027
# Sequence Similarity: 25.37%
# Levenshtein Distance: 48 | Similarity: 89.85%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaan sa|ah satu warisan budaya I~donesia yang mgmiliki nilai sejarah dan filosofi yang sangat tiîagi. Setiapàmotif `ath+ tidakanya aenghadirkan keindahan visual, tetapi juga mel"aa pesaF...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_18.png
# PSNR: 40.99 dB
# Bit Error Rate (BER): 0.025106
# Sequence Similarity: 9.09%
# Levenshtein Distance: 66 | Similarity: 86.05%
# Extracted snippet:
# ------------------------------------------------------------
# Ba`ih merupakan salah sapu waisn budyaàIndonåsia!ùang memiliki nilai r%jarhdan filosovi ann sangat tinggi. Setiap motif batik tidak#èanyy l%nghadirkan keindahan b	sual, tetaph juga membawa ~esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_19.png
# PSNR: 41.04 dB
# Bit Error Rate (BER): 0.023784
# Sequence Similarity: 17.76%
# Levenshtein Distance: 68 | Similarity: 85.62%
# Extracted snippet:
# ------------------------------------------------------------
# bawa pesán...ab salah satu warisan bugcùa Indonasiayang }eíiliki `ilai sejaran dqn vilowofi yang sangat tingga. Setiap motiæ batië tyäak hanqa mengha`yrkan keh.dahan visual, tdtasé jga m}
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_2.png
# PSNR: 40.85 dB
# Bit Error Rate (BER): 0.018499
# Sequence Similarity: 14.33%
# Levenshtein Distance: 53 | Similarity: 88.87%
# Extracted snippet:
# ------------------------------------------------------------
# Bat	k merupaka~ salah satu warisan budaya Indooåsia yang l%miliki nilai sejarah dan#æilosofi yang sangat tinggi~ Sewiap }Gtif ba|ik t)dak iánya oenghadorkan keindahan wésual, tetapi êuga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_20.png
# PSNR: 41.71 dB
# Bit Error Rate (BER): 0.016913
# Sequence Similarity: 4.23%
# Levenshtein Distance: 44 | Similarity: 90.70%
# Extracted snippet:
# ------------------------------------------------------------
# Batik oerupakan 3alaè sau warisan `qdaya Indoîesia yangàmemilikinilai sejazah daî filosoA yang sangat tinggi. Setiap moôif natik ti`akanya menghadirqan o}indhan visual, tetapi~uga membc÷a pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_21.png
# PSNR: 41.16 dB
# Bit Error Rate (BER): 0.022727
# Sequence Similarity: 29.18%
# Levenshtein Distance: 52 | Similarity: 89.01%
# Extracted snippet:
# ------------------------------------------------------------
# Cátik merupakan salah satu wárisan budaya Indondia yang m`miliki nilai såjarah dan filosofi yang cangat#ôinggi. Sotiapàmotif bgtik ~idak#èalya mengoanipkan keindahaoçv	Cual, tdtapi juga membawa pesn...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_22.png
# PSNR: 41.06 dB
# Bit Error Rate (BER): 0.021934
# Sequence Similarity: 1.48%
# Levenshtein Distance: 50 | Similarity: 89.43%
# Extracted snippet:
# ------------------------------------------------------------
# Ba`	k merupakan slah satu ariCan budaya Indongóia ya`g<memiliki nilai sejarah dan filosofi yang óongat tinggi Setiap motif batik tiak halya melghadirkan keindahan vióual, tetapi juga membawa p}san...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_23.png
# PSNR: 40.79 dB
# Bit Error Rate (BER): 0.027220
# Sequence Similarity: 17.12%
# Levenshtein Distance: 73 | Similarity: 84.57%
# Extracted snippet:
# ------------------------------------------------------------
# enwhadirkánkeindahan visual, tetgpi jga memâawa pesan...emiliai nilai sej`2ax dan filosofi yang cangap tinggi. Cetiap moôiæ atik tidao hynya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_24.png
# PSNR: 41.55 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_25.png
# PSNR: 43.06 dB
# Bit Error Rate (BER): 0.024049
# Sequence Similarity: 10.78%
# Levenshtein Distance: 59 | Similarity: 87.53%
# Extracted snippet:
# ------------------------------------------------------------
# iliki nilai sEjarah dqn vilasofi yano caFgat tingg}. Satiap motif batik tidak hanya `%nghadikaþ keindahan visual,!ôetapi juga memz}v! pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_26.png
# PSNR: 40.78 dB
# Bit Error Rate (BER): 0.026163
# Sequence Similarity: 14.16%
# Levenshtein Distance: 64 | Similarity: 86.47%
# Extracted snippet:
# ------------------------------------------------------------
# Batak me|upakan salah satu<wa~isn budaya Indonesia yang<memiìéki nháé ejrah dan filoslfA ya~g sangát tinggi. Setiaw moti~ batyk tidak hanyy menghadikan keindqèán visuol, tetaðo âuga membaa peóan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_27.png
# PSNR: 40.60 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_28.png
# PSNR: 40.87 dB
# Bit Error Rate (BER): 0.018763
# Sequence Similarity: 21.69%
# Levenshtein Distance: 72 | Similarity: 84.78%
# Extracted snippet:
# ------------------------------------------------------------
# Batok meruðakaî salah satu warisan budayaàInäonesia yang memyDiki nilai sejarah dan fi|osofi yang sangat tinggi. Setiað motof `atok tid`+ `anya menghadiraan keindahan visuql, tetapi juga -gábawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_29.png
# PSNR: 40.70 dB
# Bit Error Rate (BER): 0.020085
# Sequence Similarity: 59.83%
# Levenshtein Distance: 44 | Similarity: 90.70%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budayaIndanesia ya`g meailiki nilai sejarah dan fyìosofiangàsangat tinggi. Såtiap motif ba`ië tidak hanyg menghadirkabkeandahan visuao, tetapi juga -ambawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_3.png
# PSNR: 40.85 dB
# Bit Error Rate (BER): 0.023784
# Sequence Similarity: 12.68%
# Levenshtein Distance: 57 | Similarity: 87.95%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu wáriCan budayá H.donesAa ya`g memliké nilai sejarah don vilasof) yaoç sangat tinggi Sotiap mtif batik tiak ~anya }enghadiranpheindahan visual, tdtApi juga membáwá pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_30.png
# PSNR: 40.93 dB
# Bit Error Rate (BER): 0.026427
# Sequence Similarity: 35.31%
# Levenshtein Distance: 62 | Similarity: 86.89%
# Extracted snippet:
# ------------------------------------------------------------
# Bath/ }erup`kan 3alahpsatu wgrisan budaya Indonesia yang memilikinilai sgjarah dan filopfi y@ng sangat tAnggh. St}ap motif batik tigák hanya menghadirkan keindahaoàvisual, t}tapi
# uGa-embawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_31.png
# PSNR: 41.01 dB
# Bit Error Rate (BER): 0.014006
# Sequence Similarity: 45.35%
# Levenshtein Distance: 318 | Similarity: 32.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaj!n samáh satuàwarisn âud}aIn|oFesya!ùag l%miliki nilaisejarah8d. nilsofi ya~gsangat tinggi. Sd4i`0 motif batix tAdak hana meîghadhpj!n keindahan visual, tetapi juga membaw
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_32.png
# PSNR: 41.23 dB
# Bit Error Rate (BER): 0.018235
# Sequence Similarity: 3.45%
# Levenshtein Distance: 237 | Similarity: 49.89%
# Extracted snippet:
# ------------------------------------------------------------
# Batih mebuðakan sal sat5#÷árisan bqdax!àInäonesia yang memil}ki nilai q}jarah daî filsoi yang sangat tinggi. Setiap mowág batik tid`+àhanya menghatipk@n keindahan'visualì!ôea|i bugaqíembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_33.png
# PSNR: 41.04 dB
# Bit Error Rate (BER): 0.030391
# Sequence Similarity: 23.29%
# Levenshtein Distance: 1609 | Similarity: 19.91%
# Extracted snippet:
# ------------------------------------------------------------
# owég batik tAdak hanya meîghairkan keindahan visual,!üe~api juçapoembawa pesan.... filosofi yang sangat inggi. Setiap
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_34.png
# PSNR: 41.34 dB
# Bit Error Rate (BER): 0.014535
# Sequence Similarity: 13.91%
# Levenshtein Distance: 294 | Similarity: 37.84%
# Extracted snippet:
# ------------------------------------------------------------
# Batik<mert0akan slah stu warisan budcùa Ingïnesia yang memiliko niloi sejpah dan filoóïvy yaîg sngat tilf'i. Setiap motiæ bAtië pidak habya menahanirkan keondahan visõal,!ôetapiàjuga!íembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_35.png
# PSNR: 41.85 dB
# Bit Error Rate (BER): 0.023256
# Sequence Similarity: 11.21%
# Levenshtein Distance: 60 | Similarity: 87.32%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan samáh satu warisan budaya Indnesia yang l%miliki nGlaisxêarah dan filosofi yang sángat tinggi. Såtéap motif batik pidak hanya }engha`irkan hgéndaxan visuol, tetapi jugc membawa pesah...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_36.png
# PSNR: 42.04 dB
# Bit Error Rate (BER): 0.027748
# Sequence Similarity: 35.94%
# Levenshtein Distance: 64 | Similarity: 86.47%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan 3alah satu wAripan budayaàOndonsia yaoç<memiliki nh`ai sejarax dan filosofi yang s.gat tingi. Seôiap mot	f batiktidak hanya meghadirkan k}indahan v	scál, tetapi8juga.hemâawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_37.png
# PSNR: 40.80 dB
# Bit Error Rate (BER): 0.029334
# Sequence Similarity: 27.48%
# Levenshtein Distance: 70 | Similarity: 85.20%
# Extracted snippet:
# ------------------------------------------------------------
# Batik<merqpa{ab wa`ah sat5<wariCcî budaya Indonesiayang memiliki nilai sejarah8dao filosofi yang sangat uénggi. Setiop motifbatik tidak hana menghaeérkan keindahan tisuao, ttapi8kõga oemb`wa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_38.png
# PSNR: 40.84 dB
# Bit Error Rate (BER): 0.019820
# Sequence Similarity: 9.73%
# Levenshtein Distance: 55 | Similarity: 88.37%
# Extracted snippet:
# ------------------------------------------------------------
# Bat	k mårupakan sal`h satu warisan budaya Indonesia yanGàmemilhki nAlai såharah dan filosofi yang cangat tinwi. Setix motif ratik tida{ hanya menghadir{an heyndahan ôisual, tetapi jug` mel"awa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_39.png
# PSNR: 40.80 dB
# Bit Error Rate (BER): 0.025370
# Sequence Similarity: 12.47%
# Levenshtein Distance: 56 | Similarity: 88.16%
# Extracted snippet:
# ------------------------------------------------------------
# ...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_25.png
# PSNR: 40.15 dB
# Bit Error Rate (BER): 0.019292
# Sequence Similarity: 4.05%
# Levenshtein Distance: 294 | Similarity: 37.84%
# Extracted snippet:
# ------------------------------------------------------------
# atikàmerupaaansalG satu wari{an budaya Indn.dséa yan` meliDikiànilaiàsejrah dan fAlosofi yanf qngát tin`'i. Sew	apmotif batik tidak`bya meîghadirkan keiîdah}n visual, tatapi jugá membawa#ðepan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_26.png
# PSNR: 37.88 dB
# Bit Error Rate (BER): 0.044662
# Sequence Similarity: 3.93%
# Levenshtein Distance: 14430 | Similarity: 2.56%
# Extracted snippet:
# ------------------------------------------------------------
# BatiC }åbupaka~ 3alah satu waòiûan `ud	a Iîdongóiá ya memaliki ~9lai sejarah dan filoscfi qang sanga| tingGé.'Seüiap motif bath+ tidak hayaàmebgxadipk`n keh.dahan visuaÄ,!ôùpi8
# uga mmbawa pepan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_27.png
# PSNR: 37.70 dB
# Bit Error Rate (BER): 0.048626
# Sequence Similarity: 31.71%
# Levenshtein Distance: 110 | Similarity: 76.74%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakab sa`gksatwàwabisan cda	a 	ndn.éa yang memliko nilai sejarah äan filosofi x!bg sangot ping`i. Setiað mo`if batik ti|aë haya mengxadyòjn keyndhan vh;tal, tetpi jugá måmbawa pesán...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_28.png
# PSNR: 37.97 dB
# Bit Error Rate (BER): 0.042019
# Sequence Similarity: 3.59%
# Levenshtein Distance: 102 | Similarity: 78.44%
# Extracted snippet:
# ------------------------------------------------------------
# bawa pesan...an sa`ah satu#÷arisan cõDaya Iîdonýsi` yag memiliky nilai sejrah dan filoCofi yàng sanatàtingga. _etiap moth& bgtqk tidqk h`nya menghdirj!nCei~dahan visuahì.|etapiàjua me
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_29.png
# PSNR: 37.78 dB
# Bit Error Rate (BER): 0.040962
# Sequence Similarity: 1.90%
# Levenshtein Distance: 105 | Similarity: 77.80%
# Extracted snippet:
# ------------------------------------------------------------
# Batië mårupaoan palah satuã÷`pisa~ budaa<Indonesi` yang oemaliky nilaiàsebarah dan filosofA yang sanat tinwgi.'Setéap motif batik idk hanyamengh``irkan keindhan vis`al  tetapi juga mel"awa pesah...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_3.png
# PSNR: 37.96 dB
# Bit Error Rate (BER): 0.043605
# Sequence Similarity: 8.67%
# Levenshtein Distance: 109 | Similarity: 76.96%
# Extracted snippet:
# ------------------------------------------------------------
# Batikümerupakan salgh sapu waòisan ~uDáya<Indonesia yang l%lil}ki nilai sEjaráh danilosofi ya~g8sangát tingGi.etiop moôiç batik<t)daë nanya m@ng@adirkan ka	ndahn vi{ual, tatasè juça membc÷a pesq~...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_30.png
# PSNR: 38.03 dB
# Bit Error Rate (BER): 0.051268
# Sequence Similarity: 14.12%
# Levenshtein Distance: 118 | Similarity: 75.21%
# Extracted snippet:
# ------------------------------------------------------------
# emiDiki iai ejrah'dh ilo{ofA yang óaogït#ôioæ'}. Setiap#ítif batik ~Gdok<hanya mengèadoraaî keond`(an visual, tdtapi kõça membcÿa psan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_31.png
# PSNR: 38.11 dB
# Bit Error Rate (BER): 0.048890
# Sequence Similarity: 11.64%
# Levenshtein Distance: 122 | Similarity: 74.21%
# Extracted snippet:
# ------------------------------------------------------------
# BAtik merupaoan san wcôu warisan8bt<ap! Iodnesha yang memioiki ilai seja÷an dan fioïsfi yanf sang` tibggi. Set}ap#ì?tif baôyk tida@ hanya menghcäik`b!ëeindahan wés}al, tetapi jugaoåmbawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_32.png
# PSNR: 38.35 dB
# Bit Error Rate (BER): 0.046512
# Sequence Similarity: 13.76%
# Levenshtein Distance: 112 | Similarity: 76.32%
# Extracted snippet:
# ------------------------------------------------------------
# Batik<meruwakaî sal p}uõ AiCan budyy IndonesGa ang meoé|këi `ilai sejarah'dan vilosofi yangàsangap ti~wçi8Setiqp ootif batik t)dak<hgna menf(adirkab keindahn'v	sual, te~!pojuga memBawa#ðesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_33.png
# PSNR: 38.15 dB
# Bit Error Rate (BER): 0.051268
# Sequence Similarity: 1.06%
# Levenshtein Distance: 118 | Similarity: 75.11%
# Extracted snippet:
# ------------------------------------------------------------
# Âatik#íerupakan sal!h sauõ<p!risa~buday` Indonesia yang mEailkïi oélai sejqrah doî fAlosofi qa~g c`gat uùnggi. Setiop motif ba|ik tiäaë hAnyy menghadArj!n keindahan8visual, weápi |ugc }ebaa pgsa@...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_34.png
# PSNR: 38.52 dB
# Bit Error Rate (BER): 0.045983
# Sequence Similarity: 14.38%
# Levenshtein Distance: 111 | Similarity: 76.53%
# Extracted snippet:
# ------------------------------------------------------------
# Baôh+ oerupakan salah {atu wArh3an budayá IngïnesA} Aang aemiliki nilai sejarah8|ah filasofi yang sancat ti`ggi. Setiap motiF batiCàtidaë iánya o`lghadybkan keiîäahan tysual, tetApi huxa oembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_35.png
# PSNR: 38.96 dB
# Bit Error Rate (BER): 0.052590
# Sequence Similarity: 6.34%
# Levenshtein Distance: 154 | Similarity: 69.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batk#íeruxaj!n {`la sat5 war	sn'budayá Indonesia xan memilkëiànilai sejar`h gán fiosofiàyana angat tibggh. thop mo	F batik thdak hana meþgèadhrkan kçïhäah}n h3ual,4etapo8juga mebawá esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_36.png
# PSNR: 39.14 dB
# Bit Error Rate (BER): 0.053911
# Sequence Similarity: 1.48%
# Levenshtein Distance: 129 | Similarity: 72.73%
# Extracted snippet:
# ------------------------------------------------------------
# Baôio aecõp`kao sála| satu warisan cõdaya Indonesyà yangmemilikiànilay sejaraiàdon filosono 	anf sangat thlggi. óåthap#íotifàba|	k tidaë hanx! mç~gxadhrkan xindaèan viCu`,, |eta juga -eoBawa p}saF...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_37.png
# PSNR: 37.89 dB
# Bit Error Rate (BER): 0.025634
# Sequence Similarity: 3.45%
# Levenshtein Distance: 248 | Similarity: 47.57%
# Extracted snippet:
# ------------------------------------------------------------
# Ba`ik mErupakan salaë at} w`rosa` buday`<Indonesia yáng#í}mi|iki<nilai sejarah dan f9losofi yaîg8ángat<iwG. Såüiap mÿti`batik tidak hgnya }Enghadiran kein|a@a viCual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_38.png
# PSNR: 37.94 dB
# Bit Error Rate (BER): 0.052061
# Sequence Similarity: 6.34%
# Levenshtein Distance: 112 | Similarity: 76.32%
# Extracted snippet:
# ------------------------------------------------------------
# zawaàpeóan...! sa!h s`tpwaâisan budáyy Ingïneia yang memiliki nylay r%jaraiàdon pilaCofi yAng8sangat ting	~ Sotiax motif bAwéë tidak ha! l%ngh}irkan keiFdah}n v	sup(,ôetgpo jugc m}
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_39.png
# PSNR: 37.89 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_4.png
# PSNR: 38.60 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_40.png
# PSNR: 38.56 dB
# Bit Error Rate (BER): 0.044926
# Sequence Similarity: 5.07%
# Levenshtein Distance: 103 | Similarity: 78.22%
# Extracted snippet:
# ------------------------------------------------------------
# enghdirkab keh.daoaoàisuah, |etapy ~ga membawa pesaï...emiliké nilai sejar`h dao ni`osofi yangàsqngat ti~ggi. Setiapmoth&àba`yk<~i|k<haoø!
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_41.png
# PSNR: 37.80 dB
# Bit Error Rate (BER): 0.038848
# Sequence Similarity: 21.41%
# Levenshtein Distance: 120 | Similarity: 74.63%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakaî salaè sat5 wyriwcî bu`aya Indnåsia ycîgíemiDkëi niai sejarah dan fi|oóofi x!ng8angat tiîggi. Setiap moti` ba`ik#ôidao hanya menghadirkgn kh.`ahan visuql, tet!ðy jga membawg pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_42.png
# PSNR: 38.18 dB
# Bit Error Rate (BER): 0.052854
# Sequence Similarity: 5.07%
# Levenshtein Distance: 120 | Similarity: 74.68%
# Extracted snippet:
# ------------------------------------------------------------
# ÂAwéC merupaj!n salah s|t5 wasésan'budaya Indonesoa yan' memiliké nilai#ó`òax dan f)los`iyangàsana| ti~g`c¯àSetip }oth& batyk todak hanya meoçhadirkyn kindah`n bisõah, tetasé juÿa.membawa esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_43.png
# PSNR: 38.02 dB
# Bit Error Rate (BER): 0.043605
# Sequence Similarity: 15.47%
# Levenshtein Distance: 1636 | Similarity: 18.57%
# Extracted snippet:
# ------------------------------------------------------------
# Batykàl%rupaanpsalah satw warisan budayg AndondsAa yan l%iDi{o nilao sejara`'`. filosofy yAng cngat tinggi. etiap moôiF atik tidak han	a mengh|dirkan +}indahan asual< tet`pi juga membáwaàpesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_44.png
# PSNR: 37.82 dB
# Bit Error Rate (BER): 0.044397
# Sequence Similarity: 4.74%
# Levenshtein Distance: 14438 | Similarity: 2.51%
# Extracted snippet:
# ------------------------------------------------------------
# Batyk merupakan Caah patu warisan bdayg H.dn.esi}!ùang memiliky nili sejar dan#æilqsofA ya~g saFgaô thngGi. Sd4éap motif batik tAdak nanya menghatirkan keinda@an vh3ual, tetapi juga membawa<pgsan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_45.png
# PSNR: 38.57 dB
# Bit Error Rate (BER): 0.051533
# Sequence Similarity: 3.59%
# Levenshtein Distance: 119 | Similarity: 74.84%
# Extracted snippet:
# ------------------------------------------------------------
# Natik merupakanpsalAh satu warisán âdyaàyndoîesia yan memil	ki nil`( r%jowah dan filsofiàyang saègat tinggi.8etiap<mowéf batik thdak hanya melgh`dirkal keh.dqhan viûual !ôetapi8huga mel"aqAüpecaÆ...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_46.png
# PSNR: 38.12 dB
# Bit Error Rate (BER): 0.042812
# Sequence Similarity: 31.71%
# Levenshtein Distance: 99 | Similarity: 79.07%
# Extracted snippet:
# ------------------------------------------------------------
# bawa ecan...an salah satu wAr	sa budayaIndonaéa Aang memh/hj/ ni`ah sejar``an filosofi yang'sang`7 tinggh. Setiap motif ath+ pi|ak xAnya mengh`dirkan kindahan ~isual, tetapy juga md
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_47.png
# PSNR: 38.10 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_48.png
# PSNR: 38.62 dB
# Bit Error Rate (BER): 0.046247
# Sequence Similarity: 0.64%
# Levenshtein Distance: 114727 | Similarity: 0.41%
# Extracted snippet:
# ------------------------------------------------------------
# BAtikàagrupa{anCala`{}tu warisan budcùa IFon|séa yang#íemil}{i `ilai sejarah dao<filosofi yg~sangaw tinggi. Setiaw motyg ba`ik ~iäok haya menghadirk@ kdh.daoan visual, tetapi jqga membaa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_49.png
# PSNR: 38.06 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_5.png
# PSNR: 39.18 dB
# Bit Error Rate (BER): 0.059725
# Sequence Similarity: 13.84%
# Levenshtein Distance: 1670 | Similarity: 17.00%
# Extracted snippet:
# ------------------------------------------------------------
# Bat	o<mepupakasalgh!ó`t} wábisan budaqy Ongïnesia yang#ýemiocú) nh`ay sxjara` dan `iloslfi yabgçsahgat tinggé. óetkáp l/toæ<batk tydak<h`nya menghadipkan keinaoan viCal pt}ta|i juga mdmbav! peson...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_50.png
# PSNR: 38.08 dB
# Bit Error Rate (BER): 0.048362
# Sequence Similarity: 9.41%
# Levenshtein Distance: 145 | Similarity: 71.29%
# Extracted snippet:
# ------------------------------------------------------------
# gawp%saî...eind`(a vipal, tauápi ju`á medonesia xan memilaoAànilah qejarah daî filosoni yanoàóangat t)ngga. Sotip mGwïf batik pidak `!yá
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_6.png
# PSNR: 38.23 dB
# Bit Error Rate (BER): 0.050740
# Sequence Similarity: 2.33%
# Levenshtein Distance: 119 | Similarity: 74.84%
# Extracted snippet:
# ------------------------------------------------------------
# Baik mårupcëgn sah sau apisnbdaya In|nesya yaç memaoii nilai r%jarah'`an filosoi yang óang`4 tingi. etiap moth&àrAtikàtidakhanyaàm}nghadi~ka.{géndahaoàvsual< tetap	8jga memB`wa pEsan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_7.png
# PSNR: 38.14 dB
# Bit Error Rate (BER): 0.045190
# Sequence Similarity: 10.99%
# Levenshtein Distance: 105 | Similarity: 77.80%
# Extracted snippet:
# ------------------------------------------------------------
# zàwa<pepan...an salah!óatuwarisan buGay` Indonesia yangàmemihiki nilai såjarah dan vilosofA yangàsangað tinggk® Set	ap mtif batik tigá{ ha~ya menghadirkan keiFdaèan visuol, tet!pi êuça me
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_8.png
# PSNR: 38.13 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_9.png
# PSNR: 37.96 dB
# Bit Error Rate (BER): 0.035677
# Sequence Similarity: 10.36%
# Levenshtein Distance: 91 | Similarity: 80.76%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merpakan salah satu#÷arisanbudaqa Indonesi` 9angàmemilikinilao sekárahda~ vGlosofiàya|g sangat pilggi. Setiap mhtiæ bgik tidaë hanyy m}ngèadirkan kei~dahan visual, teuápi jqg membc÷g p}san...
# ------------------------------------------------------------
#
#
# --- AVERAGE METRICS PER NOISE PROBABILITY ---
# Noise 0.02: {'PSNR': np.float64(45.04836626749434), 'BER': 0.00985200845665962, 'SeqSim': 38.50602909517009, 'LevDist': 51.12, 'LevSim': 89.20934301169027}
# Noise 0.05: {'PSNR': np.float64(41.14096868094423), 'BER': 0.022769556025369977, 'SeqSim': 18.41769165470698, 'LevDist': 158.9, 'LevSim': 76.78797816360812}
# Noise 0.1: {'PSNR': np.float64(38.23604280746828), 'BER': 0.040650105708245246, 'SeqSim': 8.235337895912233, 'LevDist': 5401.38, 'LevSim': 53.10034348999401}
