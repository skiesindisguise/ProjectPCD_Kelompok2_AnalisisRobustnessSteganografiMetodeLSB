# %%
import cv2
import numpy as np
import os
from difflib import SequenceMatcher
import Levenshtein
import csv

# %%
# Folder to store CSV results
os.makedirs("robustness_results", exist_ok=True)
csv_path = os.path.join("robustness_results", "saltpepper_metrics.csv")

# %%
# Initialize CSV file with headers
with open(csv_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["File", "PSNR (dB)", "BER", "Sequence Similarity (%)", "Levenshtein Distance", "Levenshtein Similarity (%)", "Extracted Snippet"])

# %%
# Fungsi untuk mengubah bit menjadi text
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

# Fungsi untuk mengubah text menjadi bit
def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# %%
def extract_lsb(image_path):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    # Flatten image
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %%
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 999
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %%
# --- Function to add Salt & Pepper noise ---
def add_salt_pepper_noise(image, prob=0.02):
    noisy = np.copy(image)
    total_pixels = image.shape[0] * image.shape[1]
    num_salt = int(total_pixels * prob / 2)
    num_pepper = int(total_pixels * prob / 2)

    # Salt
    coords = [np.random.randint(0, i - 1, num_salt) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 255

    # Pepper
    coords = [np.random.randint(0, i - 1, num_pepper) for i in image.shape[:2]]
    noisy[coords[0], coords[1]] = 0

    return noisy

# %%
# --- Batch add noise ---
def batch_add_noise(folder_in, folder_out, prob=0.02):
    os.makedirs(folder_out, exist_ok=True)
    for filename in os.listdir(folder_in):
        if filename.lower().endswith(".png"):
            img = cv2.imread(os.path.join(folder_in, filename))
            noisy = add_salt_pepper_noise(img, prob)
            out_path = os.path.join(folder_out, f"noise_saltpepper_{filename}")
            cv2.imwrite(out_path, noisy)
            print("Noisy version saved:", out_path)

# %%
# --- Bit Error Rate ---
def bit_error_rate(original_text, extracted_text):
    orig_bits = text_to_bits(original_text)
    extr_bits = text_to_bits(extracted_text)

    min_len = min(len(orig_bits), len(extr_bits))
    errors = sum(1 for i in range(min_len) if orig_bits[i] != extr_bits[i])
    total = len(orig_bits)
    return errors / total if total > 0 else 0

# %%
# --- Text Similarity (SequenceMatcher) ---
def text_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio() * 100  # percentage

# %%
# --- Levenshtein Distance ---
def levenshtein_metrics(a, b):
    distance = Levenshtein.distance(a, b)
    max_len = max(len(a), len(b))
    normalized = (1 - distance / max_len) * 100 if max_len > 0 else 100
    return distance, normalized

# %%
# --- Test robustness ---
def test_robustness(stego_folder, noisy_folder, original_message):
    print("\n=== ROBUSTNESS TEST (with Levenshtein) ===")
    for filename in os.listdir(noisy_folder):
        if filename.lower().endswith(".png"):
            noisy_path = os.path.join(noisy_folder, filename)
            ori_name = filename.replace("noise_saltpepper_", "")
            ori_path = os.path.join(stego_folder, ori_name)

            extracted = extract_lsb(noisy_path)

            # --- Metrics ---
            ber = bit_error_rate(original_message, extracted)
            sim_ratio = text_similarity(original_message, extracted)
            lev_dist, lev_sim = levenshtein_metrics(original_message, extracted)

            ori = cv2.imread(ori_path)
            noisy = cv2.imread(noisy_path)
            psnr_val = psnr(ori, noisy)

            # --- Print Proof ---
            print(f"\nFile: {filename}")
            print(f"PSNR: {psnr_val:.2f} dB")
            print(f"Bit Error Rate (BER): {ber:.6f}")
            print(f"Sequence Similarity: {sim_ratio:.2f}%")
            print(f"Levenshtein Distance: {lev_dist} | Similarity: {lev_sim:.2f}%")
            print("Extracted snippet:")
            print("------------------------------------------------------------")
            print(extracted[:200] + "..." if len(extracted) > 200 else extracted)
            print("------------------------------------------------------------\n")

            # --- Save to CSV ---
            snippet = extracted[:200] + "..." if len(extracted) > 200 else extracted
            with open(csv_path, mode="a", newline="", encoding="utf-8") as file:
                writer = csv.writer(file)
                writer.writerow([
                    filename,
                    f"{psnr_val:.2f}",
                    f"{ber:.6f}",
                    f"{sim_ratio:.2f}",
                    lev_dist,
                    f"{lev_sim:.2f}",
                    snippet
                ])

# %%
# --- Run ---
if __name__ == "__main__":
    # 🟡 Original message
    message = (
        "Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. "
        "Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan dan makna yang mendalam. "
        "Motif parang, misalnya, menggambarkan kekuatan, semangat pantang menyerah, serta keberanian dalam menghadapi tantangan hidup. "
        "Sementara itu, motif kawung dipercaya melambangkan kesucian hati dan keinginan manusia untuk mencapai keseimbangan hidup."
    )

    # 🧂 Add noise and test
    batch_add_noise("stego_batik", "noise_saltpepper_batik", prob=0.02)
    test_robustness("stego_batik", "noise_saltpepper_batik", message)
# Out:
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_1.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_10.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_11.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_12.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_13.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_14.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_15.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_16.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_17.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_18.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_19.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_2.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_20.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_21.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_22.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_23.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_24.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_25.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_26.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_27.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_28.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_29.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_3.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_30.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_31.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_32.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_33.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_34.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_35.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_36.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_37.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_38.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_39.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_4.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_40.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_41.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_42.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_43.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_44.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_45.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_46.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_47.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_48.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_49.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_5.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_50.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_6.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_7.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_8.png
# Noisy version saved: noise_saltpepper_batik\noise_saltpepper_stego_9.png
#
# === ROBUSTNESS TEST (with Levenshtein) ===
#
# File: noise_saltpepper_stego_1.png
# PSNR: 44.68 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 13.74%
# Levenshtein Distance: 25 | Similarity: 94.71%
# Extracted snippet:
# ------------------------------------------------------------
# Batik l%rupaka salah satu warisan8budaya Indooesia yang memilij) nilai sejarah dan filoso`i x!ng óangat tinggi.Setiap motif batik idak hanya menghadikan keindahcî visual, Detapi juga -embawa pesao...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_10.png
# PSNR: 45.52 dB
# Bit Error Rate (BER): 0.013742
# Sequence Similarity: 37.42%
# Levenshtein Distance: 32 | Similarity: 93.23%
# Extracted snippet:
# ------------------------------------------------------------
# Bawék merupaka sal`h stu warisan budaya Indonesia yang memiliki nAlai sejara` dan filosofi yang sangat tinggi. Setiap }otif batik#ôidakhanya m}nghatirkan kdindah}n visual, tetaði huga meobawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_11.png
# PSNR: 45.06 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 70.19%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu w`bisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yyn saogat tAngçi. Setiap motif batik tidak hanya menghadirkan keindahan visual,ptetapi juga membawa pecah...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_12.png
# PSNR: 44.72 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 17.59%
# Levenshtein Distance: 63 | Similarity: 87.52%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan walah {atu warisan budaya Indonesia yan' memiliki oélai sejawah dan fioïscfi yan s`.gat tinggi. Setiap motif#âatik tidak hanya menghadirk`n keindahan vh3ual, tetapi juga membawa pes`....
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_13.png
# PSNR: 44.61 dB
# Bit Error Rate (BER): 0.007664
# Sequence Similarity: 61.73%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# BawéC merupakan salah satu warisan budaya Indonesia yan` meoéliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik todak hanyá menghadirkankeind`(}n visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_14.png
# PSNR: 44.78 dB
# Bit Error Rate (BER): 0.010307
# Sequence Similarity: 57.29%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang meailiki nilai sejaòah dan filosofi yang sangat tinggi. Setiap motif batik tidk hanya melghadirkan keinda@an visual, tetapo juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_15.png
# PSNR: 45.19 dB
# Bit Error Rate (BER): 0.003436
# Sequence Similarity: 96.41%
# Levenshtein Distance: 9 | Similarity: 98.10%
# Extracted snippet:
# ------------------------------------------------------------
# emiliki nilai sejarah dan filosofi yang pangat tioçgi. Setiap motif batik tidak hanya menghadirkan keindahan visual, tetgpi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_16.png
# PSNR: 45.21 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 55.81%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budcùaIndonesia yang meliliki nilai sejarah dan filosofi yang sangat tingg}. Sd4iap motif batik tidah hanya menghadirkAn keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_17.png
# PSNR: 45.04 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 24.10%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Btik merupakan salah satu wyrisan budayA Indonesia yang memiliki nilai sejar`h dan filosofi yang sangat tinggi. Setiap moti~ batikàtidak hanya menghadirk`n keindaha~ tisu`,, tetapi jug membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_18.png
# PSNR: 44.92 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 54.12%
# Levenshtein Distance: 27 | Similarity: 94.29%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satw warisan budaya IndonesAa yang<memilikiàni`ai sejarh dan filosofi yang sangat tinggi. Sotiap motif batik tidak hanya menghadirkanpkeindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_19.png
# PSNR: 44.95 dB
# Bit Error Rate (BER): 0.014535
# Sequence Similarity: 52.64%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Ba`ik merupakab wal!h sátu warisan budaya Indonesia yang memiliki nilah sej`2ah an filosofi yang sandat tinggi. Set	ap motif batik tidak hanya menghadirkgn keindahan vistal, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_2.png
# PSNR: 44.75 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 19.66%
# Levenshtein Distance: 28 | Similarity: 94.08%
# Extracted snippet:
# ------------------------------------------------------------
# atok merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah an nilosofi yang sangat tinggé. Setiap mo÷éf batik tidak hanya<menghadirkan +eindahan vis}al,!ôetapi juga måm`awa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_20.png
# PSNR: 45.62 dB
# Bit Error Rate (BER): 0.009249
# Sequence Similarity: 79.07%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu waisan budaya Indohesia yan memiliki nolai sejarah don filosofi yang angat tinggi. Setiap motif batik tidak nanya menghadirkan keihdahan isual, teta|i juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_21.png
# PSNR: 45.10 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 30.02%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# B`ti{ merupakan salah satu w`risan budaya Indonesia yang memiDiki nilai sejawah dan filosofi yang sangat tinggi. Setiap moti~ bgtik tidak#èanya menghadirkan keindaxan visual, tetapi juga mem`awa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_22.png
# PSNR: 44.97 dB
# Bit Error Rate (BER): 0.014271
# Sequence Similarity: 4.02%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupak`n salah satu#÷abisan budaya Indondsia yang m}milikh nilai sejarah dan filosofi yang sangat tinggi/àSetiap motif batik tidaë hanya mengh}dikgn keinda@an visual/ Detapi jugc membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_23.png
# PSNR: 44.70 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 8.25%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# enghaeérkan keindahan visual, tetapi juga membawa pesan...gmiliki nilai qejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_24.png
# PSNR: 45.52 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 71.88%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan!óala| satu waisan budaya Ondonesyá yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif by|ik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_25.png
# PSNR: 46.94 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 76.74%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Natik merupakan salah sátu warisan budaya Indonesia yang memiliai nilai sejarah dan filosofi yang sangat tinggh. Stiap motof batik t)dak<hanya menghadirkan xeindahan visual, tetapijuga me}bawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_26.png
# PSNR: 44.71 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 41.86%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Batik mepupakan walah satu warisan budáya Indonesia yang m`miìiki nilai sejarah dan fAlosof) yabg cangat tinggi. Setiap motif batik tidak hanya menghadirkan {eandahan vistal, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_27.png
# PSNR: 44.51 dB
# Bit Error Rate (BER): 0.012685
# Sequence Similarity: 7.19%
# Levenshtein Distance: 29 | Similarity: 93.87%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meòupakan salak satu warisan budaya In|onesia yang memilikiànilai seharah dan filosofi yang'sangat tinggi. Setiap motif ba`ik tidak hanya menghadipkan keindahan wè3ual/ tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_28.png
# PSNR: 44.77 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 10.15%
# Levenshtein Distance: 30 | Similarity: 93.66%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan bugaa Indonåsia yang memiliki nilai#óeêazah dan filosofi yang sangat tinggi. Set	ap mowéf batik tidak hanya oenghadirkan keindahan visual, tetapi juga memb`wa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_29.png
# PSNR: 44.62 dB
# Bit Error Rate (BER): 0.015856
# Sequence Similarity: 39.75%
# Levenshtein Distance: 38 | Similarity: 91.97%
# Extracted snippet:
# ------------------------------------------------------------
# iliki nilah sejarah dan filosofi yang sangat tinggi. Setiap motig batik tidak hanya menghadirkan keindahan visual, tetapi juga mambawa?ðesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_3.png
# PSNR: 44.79 dB
# Bit Error Rate (BER): 0.005021
# Sequence Similarity: 3.48%
# Levenshtein Distance: 268 | Similarity: 43.34%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meru@aoan salah satp v!risan budaya Indonesi` yang memiliki nilai sejarah dan filosofi yang saîgat tinggi. _etiap moti~ batik tidak hanya menghdirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_30.png
# PSNR: 44.84 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 65.75%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia ya`g memilioi nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keiodahan visual, tetapi juga meobawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_31.png
# PSNR: 44.91 dB
# Bit Error Rate (BER): 0.011628
# Sequence Similarity: 5.80%
# Levenshtein Distance: 14364 | Similarity: 3.00%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu arisan budaya Indonesia yang oemiliki#îilai sejarah dan vilosofi yang sangat tinagi. Setiap motif batik tidak hanya l%nghadirkan keindahan visual, tetapi juga membawá pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_32.png
# PSNR: 45.17 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 82.66%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik agrupáka~ salah satu warisan âudayA Indonesia yang memiliki nilai sejarah dan filosofi yang sang`< tinggi. Setiap motif batik tigák hanya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_33.png
# PSNR: 44.97 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 12.68%
# Levenshtein Distance: 27 | Similarity: 94.29%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merpakan salah satuwarisan budaya Indonesia yang memiliki nilai sebarah gán filosofi yang sangot tinggi. _etiap motif batyk tidak hanya menwhadirkán keindahan visual, tetapi juga membay pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_34.png
# PSNR: 45.26 dB
# Bit Error Rate (BER): 0.007928
# Sequence Similarity: 61.31%
# Levenshtein Distance: 19 | Similarity: 95.98%
# Extracted snippet:
# ------------------------------------------------------------
# enghadiroan keindahan visual, tetapi juga membawa pesan...Emiliki nilai sejarah dan filosofi yang sangát tinggi. Setiap mètif batik tidak hanya
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_35.png
# PSNR: 45.78 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 6.55%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Bawék merup}kan salah satu wArisan budaya yndonesia yang memiliki nilai#óejarah dan gélosofi yang sanga| tinggi. Setiap motif batik tidak hanya menghadirkan keindahan vysuaD, tetapi juga membawy esan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_36.png
# PSNR: 45.97 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 32.14%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# @atik merupakgn 3alah satu wariwan budaya Indonesia yang memiliki nilai sejarah daF filosofi yang sangaD tinggi. Setiap motif batikàtidah hanya menghadirkan keindahan visual/ tetapi jug} membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_37.png
# PSNR: 44.70 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 61.31%
# Levenshtein Distance: 29 | Similarity: 93.87%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salg` satu warisan budaya Indonesia yang memohiki nilai sejarah dan fi|osofi yang songat tinggi. Satiap motif ba`ik tidak hanya m}nghadirkan keiFdahan visual, tetapi juga meobawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_38.png
# PSNR: 44.75 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 64.48%
# Levenshtein Distance: 31 | Similarity: 93.45%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupaoan salah satu warisa` ~udaya Indoodsi` yang memiliki nilai sejarah dan filosofi yang sangat tinggi. SeDiap motif batik tidak hanya menghadorkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_39.png
# PSNR: 44.70 dB
# Bit Error Rate (BER): 0.008721
# Sequence Similarity: 70.19%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# âawa pesan...an salah satu warisanbudaya Indonesia yang memiliki nilai r%jarah dan filosofi yag sangat tinggi. Setiap motif batik tidak hanyy menghadirkan keinda@an viwual, tetapi jugapme
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_4.png
# PSNR: 45.45 dB
# Bit Error Rate (BER): 0.008985
# Sequence Similarity: 19.24%
# Levenshtein Distance: 22 | Similarity: 95.35%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meòupakan palah satu warisan budaa Indonesiapyag memiliki nilai sejarah dan filosoviyang sangat tinggi. Setiax motif batik tidakaîya menghadirkan keindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_40.png
# PSNR: 45.37 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 13.95%
# Levenshtein Distance: 19 | Similarity: 95.98%
# Extracted snippet:
# ------------------------------------------------------------
# Batik meru@aka salah satu warisan budaya Indonesia yang memiliki nhlai sebarah dan gélosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan kåindahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_41.png
# PSNR: 44.60 dB
# Bit Error Rate (BER): 0.008192
# Sequence Similarity: 50.11%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keindaha öisual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_42.png
# PSNR: 45.01 dB
# Bit Error Rate (BER): 0.007400
# Sequence Similarity: 82.45%
# Levenshtein Distance: 17 | Similarity: 96.41%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan budaya In`onesia yang memili{i nilai sejarah'dan filosofi yang sangat tinggi. Setiap mot	f batik tidak hanya menf(adirkan keindahan'visual, tetapi juga membáwa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_43.png
# PSNR: 44.85 dB
# Bit Error Rate (BER): 0.010307
# Sequence Similarity: 17.12%
# Levenshtein Distance: 26 | Similarity: 94.50%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan 3al`h s}tu v!risan àudaya 	ndonesia yang memiliki nilai sejarah dan fiìosofi yang sangat tinggi. Stiap motif batik tidak hanya menghadibkan +eindahan visual, tetapy8juga membaqa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_44.png
# PSNR: 44.63 dB
# Bit Error Rate (BER): 0.011892
# Sequence Similarity: 9.94%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakao salah satu waris`n budaya Indohesia yang memiliki nilai se~arah dan filosofi yang sangat tinggi. Setkáp motif batik tidak hanya mengxadirkal keindahan visual, tåtapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_45.png
# PSNR: 45.36 dB
# Bit Error Rate (BER): 0.012156
# Sequence Similarity: 4.49%
# Levenshtein Distance: 458 | Similarity: 3.17%
# Extracted snippet:
# ------------------------------------------------------------
# (Invalid payload)
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_46.png
# PSNR: 44.95 dB
# Bit Error Rate (BER): 0.007664
# Sequence Similarity: 12.26%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakansalah satu wgrysan budaya Indonesia yang mEmiliki nilai seêarah dan filosofi yang sangat tinogi. Setiap motif batik tidak han	a menghadirkAn keindahan visual, ttapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_47.png
# PSNR: 44.96 dB
# Bit Error Rate (BER): 0.010835
# Sequence Similarity: 68.29%
# Levenshtein Distance: 24 | Similarity: 94.93%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satu warisan buday` Indoneqia yang#íemiliki nilai sejarah dan filosofi yang sangat tinggi. Setiapàmotif batik tidqk hanya menghadirkan keindahan visual, tetapi juga membaw`?ðesa~...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_48.png
# PSNR: 45.40 dB
# Bit Error Rate (BER): 0.013214
# Sequence Similarity: 66.05%
# Levenshtein Distance: 64 | Similarity: 87.33%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupkan salah s}tu waris`n bqdáya Indonesia yang memiliki#îilai sejar}h `an fiosofi yalg sangat tinf'i. Setiap motif batik tidak hanyaàmenghadirkab keindahan visualtetyph juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_49.png
# PSNR: 44.85 dB
# Bit Error Rate (BER): 0.009778
# Sequence Similarity: 24.74%
# Levenshtein Distance: 23 | Similarity: 95.14%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satw warisan budaya Indonesia yang memiliki nilai sejarah anfAlosofi yang sangat tinggé. _etiap motif batik tidak haìx9 menghadirkan keindahan visual, teta`i juga mambawaàpesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_5.png
# PSNR: 46.01 dB
# Bit Error Rate (BER): 0.011364
# Sequence Similarity: 7.61%
# Levenshtein Distance: 27 | Similarity: 94.29%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah patu wariwan udaya Indonesia yang memiliki nilai<sejarah dan filosofi yang sa~gat#ôinggi. Sepiap motif batik tidak hanya me~ghadirkan keindhan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_50.png
# PSNR: 44.95 dB
# Bit Error Rate (BER): 0.010571
# Sequence Similarity: 34.32%
# Levenshtein Distance: 34 | Similarity: 92.87%
# Extracted snippet:
# ------------------------------------------------------------
# Batikmerupaka~ salah satu warisan budaya Indonesi yang memiliki nilai sejara` dan filosofi yang sangat tinggi. Satiap motif batik tigák hanya menahadyrkan keindahan ~iCual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_6.png
# PSNR: 45.03 dB
# Bit Error Rate (BER): 0.012421
# Sequence Similarity: 39.96%
# Levenshtein Distance: 33 | Similarity: 93.02%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merup`kan salak satu wgrisan udaya Indonesia yag memiliki nilai sejarah gán filosofi yang sangat tinggi. Setiap motif batik tidak hanya m`nghadirkan keindahan visual, tetapi juga membawa pesah...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_7.png
# PSNR: 44.92 dB
# Bit Error Rate (BER): 0.007664
# Sequence Similarity: 60.04%
# Levenshtein Distance: 18 | Similarity: 96.19%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah satuàw`risan budaya Indonesia!ùáng memiliki nilai sejarah dan f)losofi yang sangat tinggi. Setiap motif batik tidak hanya menghadirkan keondaha visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_8.png
# PSNR: 44.96 dB
# Bit Error Rate (BER): 0.008457
# Sequence Similarity: 84.14%
# Levenshtein Distance: 20 | Similarity: 95.77%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sau warióan budaya Indonesia yangàmemiliki nilai sejarah dan filosofi yang'sangat tinggi. Setiap motif batik tidak `anya menghadirkan keindahan visual, tetaph juGapmembawa pesan...
# ------------------------------------------------------------
#
#
# File: noise_saltpepper_stego_9.png
# PSNR: 44.78 dB
# Bit Error Rate (BER): 0.009514
# Sequence Similarity: 55.81%
# Levenshtein Distance: 21 | Similarity: 95.56%
# Extracted snippet:
# ------------------------------------------------------------
# Batik merupakan salah sat5 warisan ~udaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tingi. Setiqp motif ba|ik tidak hanyamenghadiran Ceiodahan visual, tetapi juga membawa pesan...
# ------------------------------------------------------------
