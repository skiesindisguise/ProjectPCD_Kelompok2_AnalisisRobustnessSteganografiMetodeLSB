# %% [markdown]
# ### Import

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import csv
import re
from skimage.metrics import peak_signal_noise_ratio as compare_psnr, structural_similarity as compare_ssim

# %% [markdown]
# ### HELPER FUCTION

# %%
# Fungsi untuk mengubah text menjadi bit
def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# Fungsi untuk mengubah bit menjadi text
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

# %% [markdown]
# ### Esktrak Hasil LSB dari Citra

# %%
def extract_lsb(image_path):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    # Flatten image
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %% [markdown]
# ### Fungsi BER (Bit Error Rate)

# %%
def bit_error_rate(original, extracted):
    if len(original) == 0:
        return 1.0
    min_len = min(len(original), len(extracted))
    diff = sum(o != e for o, e in zip(original[:min_len], extracted[:min_len]))
    return diff / min_len

# %% [markdown]
# ### Simpan citra stego ke format JPEG dengan kualitas tertentu

# %%
def compress_jpeg(input_path, output_path, quality):
    img = cv2.imread(input_path)
    cv2.imwrite(output_path, img, [int(cv2.IMWRITE_JPEG_QUALITY), quality])

# %% [markdown]
# ### Fungsi Uji Kompresi

# %%
def uji_kompresi(folder_stego, folder_out, kualitas_list=[90, 50, 10]):
    # Buat folder utama & subfolder
    folder_jpeg = os.path.join(folder_out, "jpeg")
    folder_reconv = os.path.join(folder_out, "reconverted")
    os.makedirs(folder_jpeg, exist_ok=True)
    os.makedirs(folder_reconv, exist_ok=True)

    hasil = []

    for filename in os.listdir(folder_stego):
        if not filename.lower().endswith(".png"):
            continue

        path_stego = os.path.join(folder_stego, filename)
        name = os.path.splitext(filename)[0]

        # Ekstrak pesan asli dari citra stego
        original_msg = extract_lsb(path_stego)
        original_bits = text_to_bits(original_msg)

        for q in kualitas_list:
            out_jpeg = os.path.join(folder_jpeg, f"{name}_q{q}.jpg")
            out_recovered_png = os.path.join(folder_reconv, f"{name}_q{q}_reconv.png")

            # Simpan versi terkompresi JPEG
            compress_jpeg(path_stego, out_jpeg, q)

            # Baca kembali JPEG → simpan ulang ke PNG
            img_jpeg = cv2.imread(out_jpeg)
            cv2.imwrite(out_recovered_png, img_jpeg)

            # Ekstrak pesan dari hasil konversi PNG
            extracted_msg = extract_lsb(out_recovered_png)
            extracted_bits = text_to_bits(extracted_msg)

            # Hitung BER
            ber = bit_error_rate(original_bits, extracted_bits)

            # Hitung PSNR & SSIM
            img_orig = cv2.imread(path_stego)
            psnr_val = compare_psnr(img_orig, img_jpeg)
            ssim_val = compare_ssim(
                cv2.cvtColor(img_orig, cv2.COLOR_BGR2GRAY),
                cv2.cvtColor(img_jpeg, cv2.COLOR_BGR2GRAY)
            )

            hasil.append((filename, q, psnr_val, ssim_val, ber))

            print(f"{filename} | Q={q} → PSNR={psnr_val:.2f}, SSIM={ssim_val:.3f}, BER={ber:.4f}")

    return hasil

# %% [markdown]
# ### Eksekusi Uji Kompresi

# %%
hasil_kompresi = uji_kompresi(
    folder_stego="stego_batik",
    folder_out="compression_batik",
    kualitas_list=[90, 50, 10]
)
# Out:
# stego_1.png | Q=90 → PSNR=35.93, SSIM=0.997, BER=0.3382
# stego_1.png | Q=50 → PSNR=27.54, SSIM=0.940, BER=0.3382
# stego_1.png | Q=10 → PSNR=22.72, SSIM=0.831, BER=0.3382
# stego_10.png | Q=90 → PSNR=32.27, SSIM=0.996, BER=0.3382
# stego_10.png | Q=50 → PSNR=24.55, SSIM=0.956, BER=0.3382
# stego_10.png | Q=10 → PSNR=18.94, SSIM=0.823, BER=0.3382
# stego_11.png | Q=90 → PSNR=45.56, SSIM=0.999, BER=0.3382
# stego_11.png | Q=50 → PSNR=29.30, SSIM=0.952, BER=0.3382
# stego_11.png | Q=10 → PSNR=24.24, SSIM=0.870, BER=0.3382
# stego_12.png | Q=90 → PSNR=48.48, SSIM=1.000, BER=0.3382
# stego_12.png | Q=50 → PSNR=36.05, SSIM=0.977, BER=0.3382
# stego_12.png | Q=10 → PSNR=27.29, SSIM=0.877, BER=0.3750
# stego_13.png | Q=90 → PSNR=46.84, SSIM=1.000, BER=0.3382
# stego_13.png | Q=50 → PSNR=33.19, SSIM=0.981, BER=0.3382
# stego_13.png | Q=10 → PSNR=24.63, SSIM=0.880, BER=0.3382
# stego_14.png | Q=90 → PSNR=45.61, SSIM=0.999, BER=0.3382
# stego_14.png | Q=50 → PSNR=35.39, SSIM=0.989, BER=0.3382
# stego_14.png | Q=10 → PSNR=27.29, SSIM=0.903, BER=0.3382
# stego_15.png | Q=90 → PSNR=29.44, SSIM=0.998, BER=0.3382
# stego_15.png | Q=50 → PSNR=26.08, SSIM=0.983, BER=0.3382
# stego_15.png | Q=10 → PSNR=20.83, SSIM=0.816, BER=0.3382
# stego_16.png | Q=90 → PSNR=44.45, SSIM=1.000, BER=0.3382
# stego_16.png | Q=50 → PSNR=28.43, SSIM=0.964, BER=0.3382
# stego_16.png | Q=10 → PSNR=22.32, SSIM=0.876, BER=0.3382
# stego_17.png | Q=90 → PSNR=34.91, SSIM=0.984, BER=0.3382
# stego_17.png | Q=50 → PSNR=24.92, SSIM=0.917, BER=0.3382
# stego_17.png | Q=10 → PSNR=18.43, SSIM=0.788, BER=0.3382
# stego_18.png | Q=90 → PSNR=43.80, SSIM=0.999, BER=0.3382
# stego_18.png | Q=50 → PSNR=30.09, SSIM=0.936, BER=0.3382
# stego_18.png | Q=10 → PSNR=24.27, SSIM=0.790, BER=0.3382
# stego_19.png | Q=90 → PSNR=42.76, SSIM=0.998, BER=0.3382
# stego_19.png | Q=50 → PSNR=30.82, SSIM=0.955, BER=0.3382
# stego_19.png | Q=10 → PSNR=24.61, SSIM=0.825, BER=0.3382
# stego_2.png | Q=90 → PSNR=42.78, SSIM=0.999, BER=0.3382
# stego_2.png | Q=50 → PSNR=31.20, SSIM=0.969, BER=0.3382
# stego_2.png | Q=10 → PSNR=24.78, SSIM=0.878, BER=0.3382
# stego_20.png | Q=90 → PSNR=35.63, SSIM=0.998, BER=0.3382
# stego_20.png | Q=50 → PSNR=28.70, SSIM=0.984, BER=0.3382
# stego_20.png | Q=10 → PSNR=21.78, SSIM=0.853, BER=0.3382
# stego_21.png | Q=90 → PSNR=39.11, SSIM=0.999, BER=0.3382
# stego_21.png | Q=50 → PSNR=31.06, SSIM=0.996, BER=0.3382
# stego_21.png | Q=10 → PSNR=22.38, SSIM=0.892, BER=0.3382
# stego_22.png | Q=90 → PSNR=47.60, SSIM=0.999, BER=0.3382
# stego_22.png | Q=50 → PSNR=35.81, SSIM=0.979, BER=0.3382
# stego_22.png | Q=10 → PSNR=28.71, SSIM=0.912, BER=0.3382
# stego_23.png | Q=90 → PSNR=43.41, SSIM=0.996, BER=0.3382
# stego_23.png | Q=50 → PSNR=34.18, SSIM=0.973, BER=0.3382
# stego_23.png | Q=10 → PSNR=27.66, SSIM=0.900, BER=0.3382
# stego_24.png | Q=90 → PSNR=33.57, SSIM=0.993, BER=0.3382
# stego_24.png | Q=50 → PSNR=25.62, SSIM=0.937, BER=0.3382
# stego_24.png | Q=10 → PSNR=20.16, SSIM=0.797, BER=0.3382
# stego_25.png | Q=90 → PSNR=31.95, SSIM=0.991, BER=0.3382
# stego_25.png | Q=50 → PSNR=26.60, SSIM=0.962, BER=0.3382
# stego_25.png | Q=10 → PSNR=21.70, SSIM=0.899, BER=0.3382
# stego_26.png | Q=90 → PSNR=39.31, SSIM=0.998, BER=0.3382
# stego_26.png | Q=50 → PSNR=32.51, SSIM=0.963, BER=0.3382
# stego_26.png | Q=10 → PSNR=26.40, SSIM=0.831, BER=0.3382
# stego_27.png | Q=90 → PSNR=43.06, SSIM=0.995, BER=0.3382
# stego_27.png | Q=50 → PSNR=30.24, SSIM=0.903, BER=0.3382
# stego_27.png | Q=10 → PSNR=25.48, SSIM=0.763, BER=0.3382
# stego_28.png | Q=90 → PSNR=41.17, SSIM=0.994, BER=0.3382
# stego_28.png | Q=50 → PSNR=31.89, SSIM=0.924, BER=0.3382
# stego_28.png | Q=10 → PSNR=26.28, SSIM=0.798, BER=0.3382
# stego_29.png | Q=90 → PSNR=38.62, SSIM=0.988, BER=0.3382
# stego_29.png | Q=50 → PSNR=32.35, SSIM=0.947, BER=0.3382
# stego_29.png | Q=10 → PSNR=25.79, SSIM=0.847, BER=0.3382
# stego_3.png | Q=90 → PSNR=42.97, SSIM=0.999, BER=0.3382
# stego_3.png | Q=50 → PSNR=28.41, SSIM=0.950, BER=0.3382
# stego_3.png | Q=10 → PSNR=21.97, SSIM=0.817, BER=0.3382
# stego_30.png | Q=90 → PSNR=47.25, SSIM=1.000, BER=0.3382
# stego_30.png | Q=50 → PSNR=27.58, SSIM=0.930, BER=0.3382
# stego_30.png | Q=10 → PSNR=22.26, SSIM=0.812, BER=0.4889
# stego_31.png | Q=90 → PSNR=47.86, SSIM=0.999, BER=0.3382
# stego_31.png | Q=50 → PSNR=36.11, SSIM=0.991, BER=0.3382
# stego_31.png | Q=10 → PSNR=27.03, SSIM=0.894, BER=0.3382
# stego_32.png | Q=90 → PSNR=49.15, SSIM=0.999, BER=0.3382
# stego_32.png | Q=50 → PSNR=30.02, SSIM=0.809, BER=0.3382
# stego_32.png | Q=10 → PSNR=26.29, SSIM=0.666, BER=0.3382
# stego_33.png | Q=90 → PSNR=42.52, SSIM=0.999, BER=0.3382
# stego_33.png | Q=50 → PSNR=33.71, SSIM=0.986, BER=0.3382
# stego_33.png | Q=10 → PSNR=23.22, SSIM=0.820, BER=0.3382
# stego_34.png | Q=90 → PSNR=40.32, SSIM=0.999, BER=0.3382
# stego_34.png | Q=50 → PSNR=27.69, SSIM=0.973, BER=0.3382
# stego_34.png | Q=10 → PSNR=20.85, SSIM=0.875, BER=0.3382
# stego_35.png | Q=90 → PSNR=32.17, SSIM=0.998, BER=0.3382
# stego_35.png | Q=50 → PSNR=27.69, SSIM=0.983, BER=0.3382
# stego_35.png | Q=10 → PSNR=22.60, SSIM=0.865, BER=0.3382
# stego_36.png | Q=90 → PSNR=37.05, SSIM=0.991, BER=0.3382
# stego_36.png | Q=50 → PSNR=32.94, SSIM=0.963, BER=0.3382
# stego_36.png | Q=10 → PSNR=26.84, SSIM=0.867, BER=0.3382
# stego_37.png | Q=90 → PSNR=33.95, SSIM=0.984, BER=0.3382
# stego_37.png | Q=50 → PSNR=27.44, SSIM=0.946, BER=0.3382
# stego_37.png | Q=10 → PSNR=22.22, SSIM=0.864, BER=0.3382
# stego_38.png | Q=90 → PSNR=44.41, SSIM=0.997, BER=0.3382
# stego_38.png | Q=50 → PSNR=35.42, SSIM=0.959, BER=0.3382
# stego_38.png | Q=10 → PSNR=26.79, SSIM=0.756, BER=0.3382
# stego_39.png | Q=90 → PSNR=40.80, SSIM=0.999, BER=0.3382
# stego_39.png | Q=50 → PSNR=31.50, SSIM=0.977, BER=0.3382
# stego_39.png | Q=10 → PSNR=25.31, SSIM=0.891, BER=0.3382
# stego_4.png | Q=90 → PSNR=31.46, SSIM=0.996, BER=0.3382
# stego_4.png | Q=50 → PSNR=23.36, SSIM=0.940, BER=0.3382
# stego_4.png | Q=10 → PSNR=18.13, SSIM=0.780, BER=0.3382
# stego_40.png | Q=90 → PSNR=43.46, SSIM=0.998, BER=0.3382
# stego_40.png | Q=50 → PSNR=29.39, SSIM=0.951, BER=0.3382
# stego_40.png | Q=10 → PSNR=23.82, SSIM=0.853, BER=0.3382
# stego_41.png | Q=90 → PSNR=44.91, SSIM=0.998, BER=0.3382
# stego_41.png | Q=50 → PSNR=32.33, SSIM=0.958, BER=0.3382
# stego_41.png | Q=10 → PSNR=25.06, SSIM=0.823, BER=0.3382
# stego_42.png | Q=90 → PSNR=32.93, SSIM=1.000, BER=0.3382
# stego_42.png | Q=50 → PSNR=25.39, SSIM=0.950, BER=0.3382
# stego_42.png | Q=10 → PSNR=20.86, SSIM=0.874, BER=0.3382
# stego_43.png | Q=90 → PSNR=41.71, SSIM=0.999, BER=0.3382
# stego_43.png | Q=50 → PSNR=25.03, SSIM=0.945, BER=0.3382
# stego_43.png | Q=10 → PSNR=19.94, SSIM=0.819, BER=0.3382
# stego_44.png | Q=90 → PSNR=46.70, SSIM=0.999, BER=0.3382
# stego_44.png | Q=50 → PSNR=33.31, SSIM=0.962, BER=0.3382
# stego_44.png | Q=10 → PSNR=26.58, SSIM=0.871, BER=0.3382
# stego_45.png | Q=90 → PSNR=35.28, SSIM=0.997, BER=0.3382
# stego_45.png | Q=50 → PSNR=24.74, SSIM=0.937, BER=0.3382
# stego_45.png | Q=10 → PSNR=19.27, SSIM=0.735, BER=0.5000
# stego_46.png | Q=90 → PSNR=38.73, SSIM=1.000, BER=0.3382
# stego_46.png | Q=50 → PSNR=24.55, SSIM=0.876, BER=0.3382
# stego_46.png | Q=10 → PSNR=20.33, SSIM=0.660, BER=0.3382
# stego_47.png | Q=90 → PSNR=31.30, SSIM=0.988, BER=0.3382
# stego_47.png | Q=50 → PSNR=26.24, SSIM=0.949, BER=0.3382
# stego_47.png | Q=10 → PSNR=20.91, SSIM=0.845, BER=0.3382
# stego_48.png | Q=90 → PSNR=35.45, SSIM=0.998, BER=0.3382
# stego_48.png | Q=50 → PSNR=27.35, SSIM=0.983, BER=0.3382
# stego_48.png | Q=10 → PSNR=19.48, SSIM=0.842, BER=0.3382
# stego_49.png | Q=90 → PSNR=41.22, SSIM=0.998, BER=0.3382
# stego_49.png | Q=50 → PSNR=28.03, SSIM=0.949, BER=0.3382
# stego_49.png | Q=10 → PSNR=22.57, SSIM=0.807, BER=0.3382
# stego_5.png | Q=90 → PSNR=37.88, SSIM=0.999, BER=0.3382
# stego_5.png | Q=50 → PSNR=27.85, SSIM=0.964, BER=0.3382
# stego_5.png | Q=10 → PSNR=22.02, SSIM=0.883, BER=0.3382
# stego_50.png | Q=90 → PSNR=33.59, SSIM=0.996, BER=0.3382
# stego_50.png | Q=50 → PSNR=25.79, SSIM=0.962, BER=0.3382
# stego_50.png | Q=10 → PSNR=20.18, SSIM=0.862, BER=0.3382
# stego_6.png | Q=90 → PSNR=39.04, SSIM=0.998, BER=0.3382
# stego_6.png | Q=50 → PSNR=28.13, SSIM=0.932, BER=0.3382
# stego_6.png | Q=10 → PSNR=22.78, SSIM=0.786, BER=0.3382
# stego_7.png | Q=90 → PSNR=40.72, SSIM=0.999, BER=0.3382
# stego_7.png | Q=50 → PSNR=28.04, SSIM=0.921, BER=0.3382
# stego_7.png | Q=10 → PSNR=22.69, SSIM=0.775, BER=0.3382
# stego_8.png | Q=90 → PSNR=26.64, SSIM=0.967, BER=0.3382
# stego_8.png | Q=50 → PSNR=23.09, SSIM=0.887, BER=0.3382
# stego_8.png | Q=10 → PSNR=20.30, SSIM=0.761, BER=0.3382
# stego_9.png | Q=90 → PSNR=48.50, SSIM=0.999, BER=0.3382
# stego_9.png | Q=50 → PSNR=31.21, SSIM=0.945, BER=0.3382
# stego_9.png | Q=10 → PSNR=25.38, SSIM=0.821, BER=0.3382

# %% [markdown]
# ### Visualisasi Hasil

# %%
df = pd.DataFrame(hasil_kompresi, columns=["File", "Kualitas_JPEG", "PSNR", "SSIM", "BER"])

# Hitung rata-rata untuk setiap level kualitas
avg = df.groupby("Kualitas_JPEG")[["PSNR", "SSIM", "BER"]].mean().reset_index()

# Plot PSNR dan BER
fig, ax1 = plt.subplots(figsize=(8,5))
ax1.plot(avg["Kualitas_JPEG"], avg["PSNR"], marker='o', color='tab:blue', label="PSNR (dB)")
ax1.set_xlabel("Kualitas JPEG (%)")
ax1.set_ylabel("PSNR (dB)", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(avg["Kualitas_JPEG"], avg["BER"], marker='x', color='tab:red', label="BER")
ax2.set_ylabel("Bit Error Rate", color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title("Uji Robustness terhadap Kompresi JPEG pada Citra Stego Batik")
fig.tight_layout()
plt.show()

print("\nRata-rata hasil per tingkat kualitas:")
display(avg)
# Out:
# Rata-rata hasil per tingkat kualitas:
#    Kualitas_JPEG       PSNR      SSIM       BER
# 0             10  23.246720  0.831470  0.345219
# 1             50  29.376976  0.951339  0.338235
# 2             90  39.884990  0.996301  0.338235

# %%
os.makedirs("robustness_results", exist_ok=True)
csv_path = os.path.join("robustness_results", "jpeg_compression_metrics.csv")

with open(csv_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["File", "Kualitas JPEG", "PSNR (dB)", "SSIM", "BER", "Extracted Snippet"])

print("\n=== HASIL EKSTRAKSI PESAN (KOMPRESI JPEG) ===")

# Folder hasil konversi PNG (bukan JPEG)
folder_reconv = os.path.join("compression_batik", "reconverted")

def numeric_sort(filename):
    nums = re.findall(r'\d+', filename)
    return int(nums[0]) if nums else 0

for filename in sorted(os.listdir(folder_reconv), key=numeric_sort):
    if filename.lower().endswith("_reconv.png"):
        path_extracted = os.path.join(folder_reconv, filename)
        extracted_msg = extract_lsb(path_extracted)
        snippet = extracted_msg[:200] + "..." if len(extracted_msg) > 200 else extracted_msg

        base_name = filename.split("_q")[0] + ".png"
        q_value = int(filename.split("_q")[1].split("_")[0])

        row = df[(df["File"] == base_name) & (df["Kualitas_JPEG"] == q_value)]
        if not row.empty:
            psnr_val = float(row["PSNR"].values[0])
            ssim_val = float(row["SSIM"].values[0])
            ber_val = float(row["BER"].values[0])
        else:
            psnr_val = ssim_val = ber_val = None

        print(f"\nFile: {base_name} | Q={q_value}")
        print(f"PSNR: {psnr_val:.2f} dB | SSIM: {ssim_val:.3f} | BER: {ber_val:.6f}")
        print("Extracted snippet:")
        print("------------------------------------------------------------")
        print(snippet)
        print("------------------------------------------------------------\n")

        with open(csv_path, mode="a", newline="", encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow([base_name, q_value, f"{psnr_val:.2f}", f"{ssim_val:.3f}", f"{ber_val:.6f}", snippet])
# Out:
# === HASIL EKSTRAKSI PESAN (KOMPRESI JPEG) ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 17
#      14     nums = re.findall(r'\d+', filename)
#      15     return int(nums[0]) if nums else 0
# ---> 17 for filename in sorted(os.listdir(folder_reconv), key=numeric_sort):
#      18     if filename.lower().endswith("_reconv.png"):
#      19         path_extracted = os.path.join(folder_reconv, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'uji_kompresi\\reconverted'
