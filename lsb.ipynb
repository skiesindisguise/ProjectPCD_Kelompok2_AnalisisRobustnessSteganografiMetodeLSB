# %% [markdown]
# ### IMPORT

# %%
import cv2
import numpy as np
import os

# %% [markdown]
# ### HELPER FUCTION

# %%
# Fungsi untuk mengubah text menjadi bit
def text_to_bits(text):
    return ''.join(format(ord(c), '08b') for c in text)

# Fungsi untuk mengubah bit menjadi text
def bits_to_text(bits):
    chars = []
    for i in range(0, len(bits), 8):
        byte = bits[i:i+8]
        chars.append(chr(int(byte, 2)))
    return ''.join(chars)

# %% [markdown]
# ### Convert JPG to PNG

# %%
def convert_jpg_to_png(folder_in, folder_out):
    os.makedirs(folder_out, exist_ok=True)

    for filename in os.listdir(folder_in):
        if filename.lower().endswith((".jpg", ".jpeg")):
            path = os.path.join(folder_in, filename)
            img = cv2.imread(path)
            if img is None:
                print("gagal membaca:", filename)
                continue
            name = os.path.splitext(filename)[0]
            out_path = os.path.join(folder_out, name + ".png")
            cv2.imwrite(out_path, img)
            print("converted", out_path)

        elif filename.lower().endswith(".png"):
            src = os.path.join(folder_in, filename)
            dst = os.path.join(folder_out, filename)
            cv2.imwrite(dst, cv2.imread(src))
            print("copied", dst)

    print("Konversi JPG → PNG selesai\n")

# %% [markdown]
# ### LSB Embed ke Citra Batik

# %%
def embed_lsb(image_path, message, output_path="stego.png"):

    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None

    height, width, channel = img.shape

    # Ubah pesan ke bit
    bits = text_to_bits(message)
    msg_len = len(bits)

    # 32-bit header = panjang pesan
    header = format(msg_len, '032b')
    payload = header + bits

    # Flatten image
    flat = img.flatten()
    capacity = len(flat)

    # Cek kapasitas gambar terhadap panjang pesan
    if len(payload) > capacity:
        print("pesan terlalu panjang untuk gambar ini!")
        return None
    
    # Sisipkan payload ke flatten image
    for i in range(len(payload)):
        flat[i] = (flat[i] & 0xFE) | int(payload[i])

    stego = flat.reshape((height, width, channel))
    cv2.imwrite(output_path, stego)
    print("pesan berhasil disisipkan", output_path)

    return stego

# %% [markdown]
# ### Esktrak Hasil LSB dari Citra

# %%
def extract_lsb(image_path):
    # Load image
    img = cv2.imread(image_path)
    if img is None:
        print(f"gagal membaca gambar: {image_path}")
        return None
    
    # Flatten image
    flat = img.flatten()
    total = len(flat)

    # Baca header (32 bit)
    header_bits = ""
    for i in range(32):
        header_bits += str(flat[i] & 1)

    msg_len = int(header_bits, 2)

    # msg_len <= 0, maka tidak valid
    if msg_len <= 0:
        return "(Invalid payload)"

    # kapasitas minimal, yaitu 32 header + msg_len
    if 32 + msg_len > total:
        return "(Invalid payload)"

    bits = ""
    end = 32 + msg_len

    for i in range(32, end):
        bits += str(flat[i] & 1)

    # Jika bits kurang, maka corrupted
    if len(bits) != msg_len:
        return "(Corrupted payload)"

    return bits_to_text(bits)

# %% [markdown]
# ### Fungsi Menghitung Peak Signal-to-Noise Ratio

# %%
def psnr(img1, img2):
    mse = np.mean((img1 - img2) ** 2)
    if mse == 0:
        return 999
    PIXEL_MAX = 255.0
    return 20 * np.log10(PIXEL_MAX / np.sqrt(mse))

# %% [markdown]
# ### Batch Embedding untuk image

# %%
def batch_embed(folder_in, folder_out, message):
    os.makedirs(folder_out, exist_ok=True)

    for filename in os.listdir(folder_in):
        if filename.lower().endswith(".png"):
            inp = os.path.join(folder_in, filename)
            name = os.path.splitext(filename)[0]
            outp = os.path.join(folder_out, f"stego_{name}.png")
            embed_lsb(inp, message, outp)

    print("batch embed selesai\n")

# %% [markdown]
# ### Batch Extract untuk image

# %%
def batch_extract(folder_original, folder_stego):
    results = []

    for filename in os.listdir(folder_stego):
        if filename.lower().endswith(".png"):

            stego_path = os.path.join(folder_stego, filename)
            base = filename.replace("stego_", "").replace(".png","")
            
            ori_path = None
            for ext in [".png", ".jpg", ".jpeg"]:
                test = os.path.join(folder_original, base + ext)
                if os.path.exists(test):
                    ori_path = test
                    break

            msg = extract_lsb(stego_path)

            ori = cv2.imread(ori_path) if ori_path else None
            ste = cv2.imread(stego_path)

            psnr_val = psnr(ori, ste) if ori is not None else None

            results.append((filename, msg, psnr_val))

    return results

# %% [markdown]
# ### Main Fuction

# %%
if __name__ == "__main__":

    convert_jpg_to_png("dataset_batik", "dataset_png")

    batch_embed(
        "dataset_png",
        "stego_batik",
        "Batik merupakan salah satu warisan budaya Indonesia yang memiliki nilai sejarah dan filosofi yang sangat tinggi. "
        "Setiap motif batik tidak hanya menghadirkan keindahan visual, tetapi juga membawa pesan dan makna yang mendalam. "
        "Motif parang, misalnya, menggambarkan kekuatan, semangat pantang menyerah, serta keberanian dalam menghadapi tantangan hidup. "
        "Sementara itu, motif kawung dipercaya melambangkan kesucian hati dan keinginan manusia untuk mencapai keseimbangan hidup."
    )

    res = batch_extract("dataset_png", "stego_batik")

    print("\nHasil batch extract + PSNR:")
    for fname, msg, val_psnr in res:

        # --- klasifikasi PSNR ---
        if val_psnr is None:
            kualitas = "Tidak dapat dihitung"
        elif val_psnr > 50:
            kualitas = "Sangat sangat baik (perubahan hampir mustahil terlihat)"
        elif 40 <= val_psnr <= 50:
            kualitas = "Sangat baik (perubahan tidak terlihat mata)"
        elif 30 <= val_psnr < 40:
            kualitas = "Baik, perubahan sangat kecil"
        elif 25 <= val_psnr < 30:
            kualitas = "Terlihat sedikit perubahan"
        else:
            kualitas = "Kualitas buruk, perubahan terlihat jelas"

        print(f"{fname:<25} → PSNR: {val_psnr:<8} | Kualitas: {kualitas}")
        # print(f"Pesan: {msg}\n") # Kalau ingin lihat pesan
# Out:
# converted dataset_png\1.png
# converted dataset_png\10.png
# converted dataset_png\11.png
# converted dataset_png\12.png
# converted dataset_png\13.png
# converted dataset_png\14.png
# converted dataset_png\15.png
# converted dataset_png\16.png
# converted dataset_png\17.png
# converted dataset_png\18.png
# converted dataset_png\19.png
# converted dataset_png\2.png
# converted dataset_png\20.png
# converted dataset_png\21.png
# converted dataset_png\22.png
# converted dataset_png\23.png
# converted dataset_png\24.png
# converted dataset_png\25.png
# converted dataset_png\26.png
# converted dataset_png\27.png
# converted dataset_png\28.png
# converted dataset_png\29.png
# converted dataset_png\3.png
# converted dataset_png\30.png
# converted dataset_png\31.png
# converted dataset_png\32.png
# converted dataset_png\33.png
# converted dataset_png\34.png
# converted dataset_png\35.png
# converted dataset_png\36.png
# converted dataset_png\37.png
# converted dataset_png\38.png
# converted dataset_png\39.png
# converted dataset_png\4.png
# converted dataset_png\40.png
# converted dataset_png\41.png
# converted dataset_png\42.png
# converted dataset_png\43.png
# converted dataset_png\44.png
# converted dataset_png\45.png
# converted dataset_png\46.png
# converted dataset_png\47.png
# converted dataset_png\48.png
# converted dataset_png\49.png
# converted dataset_png\5.png
# converted dataset_png\50.png
# converted dataset_png\6.png
# converted dataset_png\7.png
# converted dataset_png\8.png
# converted dataset_png\9.png
# Konversi JPG → PNG selesai
#
# pesan berhasil disisipkan stego_batik\stego_1.png
# pesan berhasil disisipkan stego_batik\stego_10.png
# pesan berhasil disisipkan stego_batik\stego_11.png
# pesan berhasil disisipkan stego_batik\stego_12.png
# pesan berhasil disisipkan stego_batik\stego_13.png
# pesan berhasil disisipkan stego_batik\stego_14.png
# pesan berhasil disisipkan stego_batik\stego_15.png
# pesan berhasil disisipkan stego_batik\stego_16.png
# pesan berhasil disisipkan stego_batik\stego_17.png
# pesan berhasil disisipkan stego_batik\stego_18.png
# pesan berhasil disisipkan stego_batik\stego_19.png
# pesan berhasil disisipkan stego_batik\stego_2.png
# pesan berhasil disisipkan stego_batik\stego_20.png
# pesan berhasil disisipkan stego_batik\stego_21.png
# pesan berhasil disisipkan stego_batik\stego_22.png
# pesan berhasil disisipkan stego_batik\stego_23.png
# pesan berhasil disisipkan stego_batik\stego_24.png
# pesan berhasil disisipkan stego_batik\stego_25.png
# pesan berhasil disisipkan stego_batik\stego_26.png
# pesan berhasil disisipkan stego_batik\stego_27.png
# pesan berhasil disisipkan stego_batik\stego_28.png
# pesan berhasil disisipkan stego_batik\stego_29.png
# pesan berhasil disisipkan stego_batik\stego_3.png
# pesan berhasil disisipkan stego_batik\stego_30.png
# pesan berhasil disisipkan stego_batik\stego_31.png
# pesan berhasil disisipkan stego_batik\stego_32.png
# pesan berhasil disisipkan stego_batik\stego_33.png
# pesan berhasil disisipkan stego_batik\stego_34.png
# pesan berhasil disisipkan stego_batik\stego_35.png
# pesan berhasil disisipkan stego_batik\stego_36.png
# pesan berhasil disisipkan stego_batik\stego_37.png
# pesan berhasil disisipkan stego_batik\stego_38.png
# pesan berhasil disisipkan stego_batik\stego_39.png
# pesan berhasil disisipkan stego_batik\stego_4.png
# pesan berhasil disisipkan stego_batik\stego_40.png
# pesan berhasil disisipkan stego_batik\stego_41.png
# pesan berhasil disisipkan stego_batik\stego_42.png
# pesan berhasil disisipkan stego_batik\stego_43.png
# pesan berhasil disisipkan stego_batik\stego_44.png
# pesan berhasil disisipkan stego_batik\stego_45.png
# pesan berhasil disisipkan stego_batik\stego_46.png
# pesan berhasil disisipkan stego_batik\stego_47.png
# pesan berhasil disisipkan stego_batik\stego_48.png
# pesan berhasil disisipkan stego_batik\stego_49.png
# pesan berhasil disisipkan stego_batik\stego_5.png
# pesan berhasil disisipkan stego_batik\stego_50.png
# pesan berhasil disisipkan stego_batik\stego_6.png
# pesan berhasil disisipkan stego_batik\stego_7.png
# pesan berhasil disisipkan stego_batik\stego_8.png
# pesan berhasil disisipkan stego_batik\stego_9.png
# batch embed selesai
#
#
# Hasil batch extract + PSNR:
# stego_1.png               → PSNR: 81.09936445144243 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_10.png              → PSNR: 69.02985472307309 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_11.png              → PSNR: 84.69272124250067 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_12.png              → PSNR: 90.95456081534672 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_13.png              → PSNR: 79.99054853855687 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_14.png              → PSNR: 80.99332125229004 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_15.png              → PSNR: 81.16770973092494 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_16.png              → PSNR: 74.67533665236259 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_17.png              → PSNR: 70.97832759355742 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_18.png              → PSNR: 75.20664003670197 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_19.png              → PSNR: 76.53096497800155 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_2.png               → PSNR: 82.71100966821092 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_20.png              → PSNR: 80.96807680099268 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_21.png              → PSNR: 80.5745406360821 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_22.png              → PSNR: 87.76102621209782 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_23.png              → PSNR: 81.56101144122304 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_24.png              → PSNR: 69.40898806208094 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_25.png              → PSNR: 73.79044006847596 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_26.png              → PSNR: 81.75636764376078 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_27.png              → PSNR: 84.93201383975995 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_28.png              → PSNR: 82.89072110446602 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_29.png              → PSNR: 74.88078391741416 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_3.png               → PSNR: 74.22444439448341 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_30.png              → PSNR: 79.97704023177624 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_31.png              → PSNR: 82.60532330956988 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_32.png              → PSNR: 79.96190673424013 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_33.png              → PSNR: 73.73675013687377 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_34.png              → PSNR: 69.43541701693506 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_35.png              → PSNR: 81.17181486352357 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_36.png              → PSNR: 83.19124869847846 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_37.png              → PSNR: 76.00728169130369 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_38.png              → PSNR: 90.12823115924891 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_39.png              → PSNR: 80.50522283400916 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_4.png               → PSNR: 69.08954104991668 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_40.png              → PSNR: 79.21239747327499 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_41.png              → PSNR: 84.16484559467318 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_42.png              → PSNR: 74.26531090751902 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_43.png              → PSNR: 76.92028246061176 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_44.png              → PSNR: 84.89841729551196 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_45.png              → PSNR: 72.43740434111014 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_46.png              → PSNR: 69.68212167105064 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_47.png              → PSNR: 70.97309074135188 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_48.png              → PSNR: 81.12983118171243 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_49.png              → PSNR: 71.48225844175612 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_5.png               → PSNR: 79.2313028004864 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_50.png              → PSNR: 73.56152647566915 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_6.png               → PSNR: 76.87689469630634 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_7.png               → PSNR: 78.80049710664858 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_8.png               → PSNR: 71.91852050461704 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
# stego_9.png               → PSNR: 87.06311231913985 | Kualitas: Sangat sangat baik (perubahan hampir mustahil terlihat)
